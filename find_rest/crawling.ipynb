# %% [markdown]
# ### [1] 구글 크롤링

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
from selenium import webdriver
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = webdriver.Chrome(options=options, executable_path='C:/chromedriver_win32/chromedriver.exe')
driver.get('https://www.google.com/maps/')
driver.implicitly_wait(3)
searchbox = driver.find_element_by_css_selector("input#searchboxinput")
searchbox.send_keys("복현1동카페")
# 검색버튼 누르기
time.sleep(2)
searchbutton = driver.find_element_by_css_selector("button#searchbox-searchbutton")
searchbutton.click()

# html = driver.page_source
# soup = BeautifulSoup(html, 'html.parser')
driver.find_element_by_css_selector("#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div:nth-child(3) > div > a").click()
time.sleep(3)
driver.find_element_by_css_selector("#QA0Szd > div > div > div.w6VYqd > div.bJzME.Hu9e2e.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf > div:nth-child(3) > div > div > button:nth-child(2) > div.LRkQ2 > div.Gpq6kf.fontTitleSmall").click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[23], line 25
#      23 driver.find_element_by_css_selector("#QA0Szd > div > div > div.w6VYqd > div.bJzME.Hu9e2e.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf > div:nth-child(3) > div > div > button:nth-child(2) > div.LRkQ2 > div.Gpq6kf.fontTitleSmall").click()
#      24 더보기 = driver.find_element_by_css_selector("button[aria-label*='리뷰 더보기']")
# ---> 25 더보기.click()
#
# File c:\Users\dddf\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:80, in WebElement.click(self)
#      78 def click(self):
#      79     """Clicks the element."""
# ---> 80     self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\dddf\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:633, in WebElement._execute(self, command, params)
#     631     params = {}
#     632 params['id'] = self._id
# --> 633 return self._parent.execute(command, params)
#
# File c:\Users\dddf\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File c:\Users\dddf\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=111.0.5563.147)

# %% [markdown]
# ### [2] 카카오 크롤링

# %% [markdown]
# #### [2-1] 카카오 url 수집

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from selenium import webdriver #pip install selenium
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import re
import time
import selenium
from selenium.webdriver.common.action_chains import ActionChains
selenium.__version__ 
def collect_kakaomap_url(text):
    path = 'C:/chromedriver_win32/chromedriver.exe'
    source_url = "https://map.kakao.com/"
    driver = webdriver.Chrome(path)
    driver.get(source_url)
    # id="search.keyword.query" 태그 선택=> input 태그 
    searchbox=driver.find_element(By.ID,"search.keyword.query") 
    searchbox.send_keys(text) #url 수집을 원하는 값 입력
    # id="search.keyword.submit" 태그 선택=> input 태그 
    searchbutton=driver.find_element(By.ID,"search.keyword.submit") 
    #script를 실행
    #arguments[0].click(); : 첫번째 매개변수값을 클릭
    driver.execute_script("arguments[0].click();", searchbutton) #검색버튼클릭.
    time.sleep(2) #2초동안 대기 =>  검색 결과가 브라우저에 표시됨
    html = driver.page_source # 현재브라우저의 소스(html)
    soup = BeautifulSoup(html, "html.parser") # BeautifulSoup 분석
    # name="a": a태그
    # attrs={"class":"moreview" : a태그중에 class속성이 moreview인 태그
    moreviews = soup.find_all(name="a", attrs={"class":"moreview"}) # 상세보기들
    page_urls = [] 
    for moreview in moreviews:
        # moreview: 한개의 상세보기. a태그
        page_url = moreview.get("href") # a태그의 href 속성의 값
        page_urls.append(page_url) #상세보기의 href 속성값들 목록. 강남역 고기집의 URL 정보 목록
    # driver.close()    
    more_place = driver.find_element_by_xpath('//*[@id="info.search.place.more"]')

    actions = ActionChains(driver )#스크롤내리기
    actions.move_to_element(more_place).perform()
    time.sleep(1)
    more_place = driver.find_element_by_xpath('/html/body/div[10]/div/div/div/span')
    more_place.click()
    try:
        more_place.click()
    except:
        more_place = driver.find_element_by_xpath('/html/body/div[5]/div[2]/div[1]/div[7]/div[5]/a')
        more_place.click()
    page_num = 3
    while True:
        time.sleep(1.5)
        html = driver.page_source # 현재브라우저의 소스(html)
        soup = BeautifulSoup(html, "html.parser") # BeautifulSoup 분석
        # name="a": a태그
        # attrs={"class":"moreview" : a태그중에 class속성이 moreview인 태그
        moreviews = soup.find_all(name="a", attrs={"class":"moreview"}) # 상세보기들
        
        for moreview in moreviews:
            # moreview: 한개의 상세보기. a태그
            page_url = moreview.get("href") # a태그의 href 속성의 값
            page_urls.append(page_url) #상세보기의 href 속성값들 목록. 강남역 고기집의 URL 정보 목록
        try:# 페이지 버튼마다 반복 없을 시 다음 페이지로 선택
            page_button = driver.find_element_by_css_selector('#info\.search\.page\.no{}'.format(page_num))
            page_num += 1
        except Exception:
            page_button = driver.find_element_by_css_selector('#info\.search\.page\.next')
            page_num = 2
            
        try:#버튼 클릭 및 요소가 없을 시 break
            page_button.click()
        except:
            
            break
    return page_urls

# %%
page_urls = collect_kakaomap_url('수분크림')
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 page_urls = collect_kakaomap_url('대구 복현동 맛집')
#
# Cell In[1], line 53, in collect_kakaomap_url(text)
#      51 while True:
#      52     time.sleep(3)
# ---> 53     html = driver.page_source # 현재브라우저의 소스(html)
#      54     soup = BeautifulSoup(html, "html.parser") # BeautifulSoup 분석
#      55     # name="a": a태그
#      56     # attrs={"class":"moreview" : a태그중에 class속성이 moreview인 태그
#
# File c:\Users\dddf\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:679, in WebDriver.page_source(self)
#     671 @property
#     672 def page_source(self):
#     673     """
#     674     Gets the source of the current page.
#     675
#     676     :Usage:
#     677         driver.page_source
#     678     """
# --> 679     return self.execute(Command.GET_PAGE_SOURCE)['value']
#
# File c:\Users\dddf\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File c:\Users\dddf\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=111.0.5563.147)

# %%
len(page_urls)
# Out:
# 500

# %%
page_urls
# Out:
# ['https://place.map.kakao.com/95713992',
#  'https://place.map.kakao.com/1503746075',
#  'https://place.map.kakao.com/2011092566',
#  'https://place.map.kakao.com/741391811',
#  'https://place.map.kakao.com/168079537',
#  'https://place.map.kakao.com/1052874675',
#  'https://place.map.kakao.com/1648266796',
#  'https://place.map.kakao.com/27238067',
#  'https://place.map.kakao.com/26573718',
#  'https://place.map.kakao.com/263830255',
#  'https://place.map.kakao.com/1511737742',
#  'https://place.map.kakao.com/1780387311',
#  'https://place.map.kakao.com/56929632',
#  'https://place.map.kakao.com/27511865',
#  'https://place.map.kakao.com/279490770',
#  'https://place.map.kakao.com/785573131',
#  'https://place.map.kakao.com/1907052666',
#  'https://place.map.kakao.com/27463588',
#  'https://place.map.kakao.com/12997393',
#  'https://place.map.kakao.com/609286803',
#  'https://place.map.kakao.com/855757075',
#  'https://place.map.kakao.com/7912852',
#  'https://place.map.kakao.com/2000332368',
#  'https://place.map.kakao.com/1332451453',
#  'https://place.map.kakao.com/2023940427',
#  'https://place.map.kakao.com/2021432189',
#  'https://place.map.kakao.com/353333104',
#  'https://place.map.kakao.com/7976701',
#  'https://place.map.kakao.com/18099336',
#  'https://place.map.kakao.com/21440993',
#  'https://place.map.kakao.com/182416476',
#  'https://place.map.kakao.com/27290706',
#  'https://place.map.kakao.com/260216497',
#  'https://place.map.kakao.com/27347288',
#  'https://place.map.kakao.com/27315574',
#  'https://place.map.kakao.com/2121791662',
#  'https://place.map.kakao.com/14095777',
#  'https://place.map.kakao.com/393701929',
#  'https://place.map.kakao.com/1128885704',
#  'https://place.map.kakao.com/1464212890',
#  'https://place.map.kakao.com/13559752',
#  'https://place.map.kakao.com/27290655',
#  'https://place.map.kakao.com/27402001',
#  'https://place.map.kakao.com/844552938',
#  'https://place.map.kakao.com/1364306049',
#  'https://place.map.kakao.com/16683904',
#  'https://place.map.kakao.com/8600335',
#  'https://place.map.kakao.com/1816543690',
#  'https://place.map.kakao.com/1074536793',
#  'https://place.map.kakao.com/1974135812',
#  'https://place.map.kakao.com/1727429798',
#  'https://place.map.kakao.com/8680507',
#  'https://place.map.kakao.com/27323467',
#  'https://place.map.kakao.com/1161575093',
#  'https://place.map.kakao.com/1111006760',
#  'https://place.map.kakao.com/300109175',
#  'https://place.map.kakao.com/2015065724',
#  'https://place.map.kakao.com/1262576514',
#  'https://place.map.kakao.com/893416365',
#  'https://place.map.kakao.com/44032268',
#  'https://place.map.kakao.com/1519347464',
#  'https://place.map.kakao.com/12519094',
#  'https://place.map.kakao.com/26235461',
#  'https://place.map.kakao.com/1460356406',
#  'https://place.map.kakao.com/881493948',
#  'https://place.map.kakao.com/16038029',
#  'https://place.map.kakao.com/1053016183',
#  'https://place.map.kakao.com/1186661550',
#  'https://place.map.kakao.com/27316512',
#  'https://place.map.kakao.com/14517939',
#  'https://place.map.kakao.com/826926971',
#  'https://place.map.kakao.com/859855083',
#  'https://place.map.kakao.com/1572666841',
#  'https://place.map.kakao.com/8323721',
#  'https://place.map.kakao.com/23258922',
#  'https://place.map.kakao.com/13112670',
#  'https://place.map.kakao.com/1525298028',
#  'https://place.map.kakao.com/684652072',
#  'https://place.map.kakao.com/18546298',
#  'https://place.map.kakao.com/1458304666',
#  'https://place.map.kakao.com/629063628',
#  'https://place.map.kakao.com/26814353',
#  'https://place.map.kakao.com/1331446685',
#  'https://place.map.kakao.com/27323355',
#  'https://place.map.kakao.com/1419134399',
#  'https://place.map.kakao.com/1585722322',
#  'https://place.map.kakao.com/52175603',
#  'https://place.map.kakao.com/2105252324',
#  'https://place.map.kakao.com/574289045',
#  'https://place.map.kakao.com/20181717',
#  'https://place.map.kakao.com/77153801',
#  'https://place.map.kakao.com/52888442',
#  'https://place.map.kakao.com/25506793',
#  'https://place.map.kakao.com/19357421',
#  'https://place.map.kakao.com/312908843',
#  'https://place.map.kakao.com/2108134415',
#  'https://place.map.kakao.com/1689194201',
#  'https://place.map.kakao.com/12758988',
#  'https://place.map.kakao.com/72733906',
#  'https://place.map.kakao.com/1272553949',
#  'https://place.map.kakao.com/380650186',
#  'https://place.map.kakao.com/721892007',
#  'https://place.map.kakao.com/1615025025',
#  'https://place.map.kakao.com/571204025',
#  'https://place.map.kakao.com/19346141',
#  'https://place.map.kakao.com/27288694',
#  'https://place.map.kakao.com/2052059967',
#  'https://place.map.kakao.com/1969942230',
#  'https://place.map.kakao.com/1090628343',
#  'https://place.map.kakao.com/11237597',
#  'https://place.map.kakao.com/1206414848',
#  'https://place.map.kakao.com/9567094',
#  'https://place.map.kakao.com/12435058',
#  'https://place.map.kakao.com/24944006',
#  'https://place.map.kakao.com/27463995',
#  'https://place.map.kakao.com/311828701',
#  'https://place.map.kakao.com/193827637',
#  'https://place.map.kakao.com/628561457',
#  'https://place.map.kakao.com/26465424',
#  'https://place.map.kakao.com/504824260',
#  'https://place.map.kakao.com/569698347',
#  'https://place.map.kakao.com/26615114',
#  'https://place.map.kakao.com/1939290114',
#  'https://place.map.kakao.com/49253730',
#  'https://place.map.kakao.com/27270313',
#  'https://place.map.kakao.com/31188196',
#  'https://place.map.kakao.com/194854751',
#  'https://place.map.kakao.com/27226029',
#  'https://place.map.kakao.com/127438589',
#  'https://place.map.kakao.com/762214594',
#  'https://place.map.kakao.com/1005870320',
#  'https://place.map.kakao.com/13305293',
#  'https://place.map.kakao.com/2045551139',
#  'https://place.map.kakao.com/1158999076',
#  'https://place.map.kakao.com/1053910065',
#  'https://place.map.kakao.com/16793278',
#  'https://place.map.kakao.com/1327345377',
#  'https://place.map.kakao.com/1420575233',
#  'https://place.map.kakao.com/1203177765',
#  'https://place.map.kakao.com/1196490248',
#  'https://place.map.kakao.com/13287052',
#  'https://place.map.kakao.com/49084717',
#  'https://place.map.kakao.com/17884673',
#  'https://place.map.kakao.com/16297490',
#  'https://place.map.kakao.com/20950984',
#  'https://place.map.kakao.com/642822275',
#  'https://place.map.kakao.com/27174599',
#  'https://place.map.kakao.com/892029708',
#  'https://place.map.kakao.com/27474189',
#  'https://place.map.kakao.com/27440874',
#  'https://place.map.kakao.com/88155904',
#  'https://place.map.kakao.com/1947251235',
#  'https://place.map.kakao.com/1618947990',
#  'https://place.map.kakao.com/189337403',
#  'https://place.map.kakao.com/8007070',
#  'https://place.map.kakao.com/2005979161',
#  'https://place.map.kakao.com/316697838',
#  'https://place.map.kakao.com/97723360',
#  'https://place.map.kakao.com/16329129',
#  'https://place.map.kakao.com/1586412553',
#  'https://place.map.kakao.com/10119238',
#  'https://place.map.kakao.com/1674958307',
#  'https://place.map.kakao.com/1860026973',
#  'https://place.map.kakao.com/16560213',
#  'https://place.map.kakao.com/1068840754',
#  'https://place.map.kakao.com/8034320',
#  'https://place.map.kakao.com/11493134',
#  'https://place.map.kakao.com/26878765',
#  'https://place.map.kakao.com/1350808227',
#  'https://place.map.kakao.com/675124313',
#  'https://place.map.kakao.com/2106991405',
#  'https://place.map.kakao.com/1893918990',
#  'https://place.map.kakao.com/1534364012',
#  'https://place.map.kakao.com/716216301',
#  'https://place.map.kakao.com/94846495',
#  'https://place.map.kakao.com/1236078779',
#  'https://place.map.kakao.com/980714762',
#  'https://place.map.kakao.com/11825068',
#  'https://place.map.kakao.com/825929767',
#  'https://place.map.kakao.com/1864002852',
#  'https://place.map.kakao.com/1169947257',
#  'https://place.map.kakao.com/21418785',
#  'https://place.map.kakao.com/118575691',
#  'https://place.map.kakao.com/12684093',
#  'https://place.map.kakao.com/2022018763',
#  'https://place.map.kakao.com/1709033266',
#  'https://place.map.kakao.com/1347944544',
#  'https://place.map.kakao.com/735756593',
#  'https://place.map.kakao.com/8735236',
#  'https://place.map.kakao.com/14736365',
#  'https://place.map.kakao.com/2015368549',
#  'https://place.map.kakao.com/798177737',
#  'https://place.map.kakao.com/1481448059',
#  'https://place.map.kakao.com/1383801747',
#  'https://place.map.kakao.com/26915577',
#  'https://place.map.kakao.com/1551638178',
#  'https://place.map.kakao.com/23066867',
#  'https://place.map.kakao.com/1426583069',
#  'https://place.map.kakao.com/8153040',
#  'https://place.map.kakao.com/16963841',
#  'https://place.map.kakao.com/1628828402',
#  'https://place.map.kakao.com/24267245',
#  'https://place.map.kakao.com/237736742',
#  'https://place.map.kakao.com/2000630247',
#  'https://place.map.kakao.com/1970283695',
#  'https://place.map.kakao.com/16048633',
#  'https://place.map.kakao.com/183801935',
#  'https://place.map.kakao.com/7906948',
#  'https://place.map.kakao.com/21332525',
#  'https://place.map.kakao.com/845286986',
#  'https://place.map.kakao.com/21332255',
#  'https://place.map.kakao.com/745713828',
#  'https://place.map.kakao.com/16906836',
#  'https://place.map.kakao.com/292604493',
#  'https://place.map.kakao.com/101220860',
#  'https://place.map.kakao.com/1005263476',
#  'https://place.map.kakao.com/27315759',
#  'https://place.map.kakao.com/1091694699',
#  'https://place.map.kakao.com/1034412965',
#  'https://place.map.kakao.com/1090961290',
#  'https://place.map.kakao.com/1498205952',
#  'https://place.map.kakao.com/19901835',
#  'https://place.map.kakao.com/16037922',
#  'https://place.map.kakao.com/16055635',
#  'https://place.map.kakao.com/726835937',
#  'https://place.map.kakao.com/171885256',
#  'https://place.map.kakao.com/1350394858',
#  'https://place.map.kakao.com/16065467',
#  'https://place.map.kakao.com/1353935275',
#  'https://place.map.kakao.com/16061668',
#  'https://place.map.kakao.com/796457638',
#  'https://place.map.kakao.com/281388651',
#  'https://place.map.kakao.com/25770215',
#  'https://place.map.kakao.com/21025569',
#  'https://place.map.kakao.com/429876967',
#  'https://place.map.kakao.com/1606213986',
#  'https://place.map.kakao.com/16619900',
#  'https://place.map.kakao.com/745711472',
#  'https://place.map.kakao.com/2035074380',
#  'https://place.map.kakao.com/1235425275',
#  'https://place.map.kakao.com/2060584279',
#  'https://place.map.kakao.com/767666704',
#  'https://place.map.kakao.com/16046486',
#  'https://place.map.kakao.com/18258687',
#  'https://place.map.kakao.com/495667742',
#  'https://place.map.kakao.com/620843167',
#  'https://place.map.kakao.com/1317179431',
#  'https://place.map.kakao.com/403548943',
#  'https://place.map.kakao.com/26794834',
#  'https://place.map.kakao.com/1007169210',
#  'https://place.map.kakao.com/8115545',
#  'https://place.map.kakao.com/14712022',
#  'https://place.map.kakao.com/26878761',
#  'https://place.map.kakao.com/2011228',
#  'https://place.map.kakao.com/16472450',
#  'https://place.map.kakao.com/8846917',
#  'https://place.map.kakao.com/463465189',
#  'https://place.map.kakao.com/1916742796',
#  'https://place.map.kakao.com/13301912',
#  'https://place.map.kakao.com/7891890',
#  'https://place.map.kakao.com/227102188',
#  'https://place.map.kakao.com/26902582',
#  'https://place.map.kakao.com/424545378',
#  'https://place.map.kakao.com/26537868',
#  'https://place.map.kakao.com/1360223333',
#  'https://place.map.kakao.com/1800275557',
#  'https://place.map.kakao.com/1821750034',
#  'https://place.map.kakao.com/1977332252',
#  'https://place.map.kakao.com/945118239',
#  'https://place.map.kakao.com/27440129',
#  'https://place.map.kakao.com/1283690037',
#  'https://place.map.kakao.com/21331948',
#  'https://place.map.kakao.com/56611446',
#  'https://place.map.kakao.com/618834212',
#  'https://place.map.kakao.com/1936749192',
#  'https://place.map.kakao.com/1660939960',
#  'https://place.map.kakao.com/13333278',
#  'https://place.map.kakao.com/2023648781',
#  'https://place.map.kakao.com/409501549',
#  'https://place.map.kakao.com/1628694831',
#  'https://place.map.kakao.com/189014165',
#  'https://place.map.kakao.com/10148306',
#  'https://place.map.kakao.com/1771756773',
#  'https://place.map.kakao.com/471472052',
#  'https://place.map.kakao.com/135865518',
#  'https://place.map.kakao.com/1649471753',
#  'https://place.map.kakao.com/781440719',
#  'https://place.map.kakao.com/16055434',
#  'https://place.map.kakao.com/1422750934',
#  'https://place.map.kakao.com/1289979041',
#  'https://place.map.kakao.com/20029314',
#  'https://place.map.kakao.com/186152068',
#  'https://place.map.kakao.com/20376362',
#  'https://place.map.kakao.com/21237892',
#  'https://place.map.kakao.com/9475630',
#  'https://place.map.kakao.com/24528855',
#  'https://place.map.kakao.com/16647845',
#  'https://place.map.kakao.com/13061752',
#  'https://place.map.kakao.com/796254251',
#  'https://place.map.kakao.com/123420283',
#  'https://place.map.kakao.com/273630592',
#  'https://place.map.kakao.com/22052567',
#  'https://place.map.kakao.com/1467746639',
#  'https://place.map.kakao.com/343293762',
#  'https://place.map.kakao.com/17805965',
#  'https://place.map.kakao.com/1765205584',
#  'https://place.map.kakao.com/1086342860',
#  'https://place.map.kakao.com/1727176654',
#  'https://place.map.kakao.com/1261894710',
#  'https://place.map.kakao.com/642973308',
#  'https://place.map.kakao.com/129894347',
#  'https://place.map.kakao.com/803886641',
#  'https://place.map.kakao.com/9607524',
#  'https://place.map.kakao.com/1296615525',
#  'https://place.map.kakao.com/515930750',
#  'https://place.map.kakao.com/1723419685',
#  'https://place.map.kakao.com/1866851283',
#  'https://place.map.kakao.com/600474417',
#  'https://place.map.kakao.com/1967338071',
#  'https://place.map.kakao.com/9412618',
#  'https://place.map.kakao.com/1098388849',
#  'https://place.map.kakao.com/966657032',
#  'https://place.map.kakao.com/16048819',
#  'https://place.map.kakao.com/1182421805',
#  'https://place.map.kakao.com/1287462485',
#  'https://place.map.kakao.com/791112961',
#  'https://place.map.kakao.com/859039049',
#  'https://place.map.kakao.com/497345589',
#  'https://place.map.kakao.com/1748412145',
#  'https://place.map.kakao.com/573478883',
#  'https://place.map.kakao.com/16620520',
#  'https://place.map.kakao.com/960675289',
#  'https://place.map.kakao.com/259136855',
#  'https://place.map.kakao.com/534621290',
#  'https://place.map.kakao.com/24751749',
#  'https://place.map.kakao.com/1764902265',
#  'https://place.map.kakao.com/723934955',
#  'https://place.map.kakao.com/2146897452',
#  'https://place.map.kakao.com/19215962',
#  'https://place.map.kakao.com/1053955684',
#  'https://place.map.kakao.com/16794929',
#  'https://place.map.kakao.com/364765331',
#  'https://place.map.kakao.com/25132437',
#  'https://place.map.kakao.com/472935212',
#  'https://place.map.kakao.com/27548134',
#  'https://place.map.kakao.com/1135146105',
#  'https://place.map.kakao.com/1424882368',
#  'https://place.map.kakao.com/27340797',
#  'https://place.map.kakao.com/16678542',
#  'https://place.map.kakao.com/16062705',
#  'https://place.map.kakao.com/1336359266',
#  'https://place.map.kakao.com/1549409058',
#  'https://place.map.kakao.com/337194538',
#  'https://place.map.kakao.com/2058841038',
#  'https://place.map.kakao.com/14863714',
#  'https://place.map.kakao.com/19120526',
#  'https://place.map.kakao.com/1848470602',
#  'https://place.map.kakao.com/1196999232',
#  'https://place.map.kakao.com/387631786',
#  'https://place.map.kakao.com/13074656',
#  'https://place.map.kakao.com/26829542',
#  'https://place.map.kakao.com/27346559',
#  'https://place.map.kakao.com/26781592',
#  'https://place.map.kakao.com/26431428',
#  'https://place.map.kakao.com/719746566',
#  'https://place.map.kakao.com/1613247268',
#  'https://place.map.kakao.com/1306173213',
#  'https://place.map.kakao.com/26819710',
#  'https://place.map.kakao.com/2069996905',
#  'https://place.map.kakao.com/1915340378',
#  'https://place.map.kakao.com/825354076',
#  'https://place.map.kakao.com/14519320',
#  'https://place.map.kakao.com/45473966',
#  'https://place.map.kakao.com/14919114',
#  'https://place.map.kakao.com/27217610',
#  'https://place.map.kakao.com/1459301709',
#  'https://place.map.kakao.com/13809885',
#  'https://place.map.kakao.com/27273657',
#  'https://place.map.kakao.com/1532164544',
#  'https://place.map.kakao.com/1866698807',
#  'https://place.map.kakao.com/191243479',
#  'https://place.map.kakao.com/16906097',
#  'https://place.map.kakao.com/759335911',
#  'https://place.map.kakao.com/94505617',
#  'https://place.map.kakao.com/839844752',
#  'https://place.map.kakao.com/689702595',
#  'https://place.map.kakao.com/12752696',
#  'https://place.map.kakao.com/944431508',
#  'https://place.map.kakao.com/1176601357',
#  'https://place.map.kakao.com/172518909',
#  'https://place.map.kakao.com/1285514239',
#  'https://place.map.kakao.com/418825708',
#  'https://place.map.kakao.com/16792506',
#  'https://place.map.kakao.com/23985599',
#  'https://place.map.kakao.com/463179829',
#  'https://place.map.kakao.com/8535258',
#  'https://place.map.kakao.com/1454349874',
#  'https://place.map.kakao.com/2064369850',
#  'https://place.map.kakao.com/21572919',
#  'https://place.map.kakao.com/8156061',
#  'https://place.map.kakao.com/533385702',
#  'https://place.map.kakao.com/1664465944',
#  'https://place.map.kakao.com/937002908',
#  'https://place.map.kakao.com/7901127',
#  'https://place.map.kakao.com/9228524',
#  'https://place.map.kakao.com/1455068020',
#  'https://place.map.kakao.com/1801807365',
#  'https://place.map.kakao.com/814556502',
#  'https://place.map.kakao.com/342517387',
#  'https://place.map.kakao.com/284532123',
#  'https://place.map.kakao.com/151456777',
#  'https://place.map.kakao.com/1961135055',
#  'https://place.map.kakao.com/26410902',
#  'https://place.map.kakao.com/16791213',
#  'https://place.map.kakao.com/13293580',
#  'https://place.map.kakao.com/293690686',
#  'https://place.map.kakao.com/144907267',
#  'https://place.map.kakao.com/12337871',
#  'https://place.map.kakao.com/1859802579',
#  'https://place.map.kakao.com/944164380',
#  'https://place.map.kakao.com/10373793',
#  'https://place.map.kakao.com/27272831',
#  'https://place.map.kakao.com/1001076152',
#  'https://place.map.kakao.com/1736340873',
#  'https://place.map.kakao.com/27293344',
#  'https://place.map.kakao.com/1678250154',
#  'https://place.map.kakao.com/16620249',
#  'https://place.map.kakao.com/12783814',
#  'https://place.map.kakao.com/26942050',
#  'https://place.map.kakao.com/1942399413',
#  'https://place.map.kakao.com/25782422',
#  'https://place.map.kakao.com/7394649',
#  'https://place.map.kakao.com/1381086019',
#  'https://place.map.kakao.com/854349717',
#  'https://place.map.kakao.com/23841842',
#  'https://place.map.kakao.com/1299243399',
#  'https://place.map.kakao.com/1100401024',
#  'https://place.map.kakao.com/2140166026',
#  'https://place.map.kakao.com/1474989677',
#  'https://place.map.kakao.com/1217434650',
#  'https://place.map.kakao.com/19117858',
#  'https://place.map.kakao.com/2135152674',
#  'https://place.map.kakao.com/1561071736',
#  'https://place.map.kakao.com/16591823',
#  'https://place.map.kakao.com/10489858',
#  'https://place.map.kakao.com/283397445',
#  'https://place.map.kakao.com/1776637227',
#  'https://place.map.kakao.com/1275434716',
#  'https://place.map.kakao.com/17707890',
#  'https://place.map.kakao.com/8328932',
#  'https://place.map.kakao.com/8692452',
#  'https://place.map.kakao.com/2040305619',
#  'https://place.map.kakao.com/681739572',
#  'https://place.map.kakao.com/429290256',
#  'https://place.map.kakao.com/27290728',
#  'https://place.map.kakao.com/10082619',
#  'https://place.map.kakao.com/23253771',
#  'https://place.map.kakao.com/1913263383',
#  'https://place.map.kakao.com/19635600',
#  'https://place.map.kakao.com/647708334',
#  'https://place.map.kakao.com/1836943006',
#  'https://place.map.kakao.com/27249352',
#  'https://place.map.kakao.com/27280955',
#  'https://place.map.kakao.com/1430257266',
#  'https://place.map.kakao.com/1382636348',
#  'https://place.map.kakao.com/13287017',
#  'https://place.map.kakao.com/826711186',
#  'https://place.map.kakao.com/27310529',
#  'https://place.map.kakao.com/16036307',
#  'https://place.map.kakao.com/22875058',
#  'https://place.map.kakao.com/775161244',
#  'https://place.map.kakao.com/1627001384',
#  'https://place.map.kakao.com/1621224124',
#  'https://place.map.kakao.com/2000969854',
#  'https://place.map.kakao.com/16055100',
#  'https://place.map.kakao.com/27158491',
#  'https://place.map.kakao.com/1451039147',
#  'https://place.map.kakao.com/816498360',
#  'https://place.map.kakao.com/1361794682',
#  'https://place.map.kakao.com/27219079',
#  'https://place.map.kakao.com/10274878',
#  'https://place.map.kakao.com/2038287288',
#  'https://place.map.kakao.com/460943489',
#  'https://place.map.kakao.com/13293087',
#  'https://place.map.kakao.com/23060107',
#  'https://place.map.kakao.com/1143102917',
#  'https://place.map.kakao.com/13289483',
#  'https://place.map.kakao.com/49807564',
#  'https://place.map.kakao.com/531482716',
#  'https://place.map.kakao.com/344803080',
#  'https://place.map.kakao.com/12997153',
#  'https://place.map.kakao.com/16793158',
#  'https://place.map.kakao.com/1588991396',
#  'https://place.map.kakao.com/733935260',
#  'https://place.map.kakao.com/18504510',
#  'https://place.map.kakao.com/21133288',
#  'https://place.map.kakao.com/23106242',
#  'https://place.map.kakao.com/772858218',
#  'https://place.map.kakao.com/27347074',
#  'https://place.map.kakao.com/2053870761']

# %% [markdown]
# ---
# # URL 1개에 대한 df생성
# ---

# %%
# 상세보기에 조회된 고기집 목록을 조회
path = 'C:/chromedriver_win32/chromedriver.exe'
df = pd.DataFrame() # 컬럼만 조회
driver = webdriver.Chrome(path) # 브라우저 실행
# for page in page_urls:
df = pd.DataFrame()
time.sleep(1)
# for page in page_urls:
driver.get(page_urls[30]) # 식당 데이터 상세화면
time.sleep(2) # 2초 쉬기
html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
soup = BeautifulSoup(html, 'html.parser')


total_strong = soup.find(name="strong", attrs={"class": "total_evaluation"})
try:
    tot_num = total_strong.find(name="span", attrs={"class": "color_b"}) # 등록된 리뷰 갯수
except:
    pass
    # continue
if int(tot_num.text) == 0:
    pass
    # continue
more_text_num= ((int(tot_num.text)-3)//5)
time.sleep(1)
while True:
    if more_text_num >3:
        # try:
        more_text_in_store = driver.find_element_by_css_selector('span.txt_more')
            # more_text_in_store = driver.find_element_by_xpath('//*[@id="mArticle"]/div[7]/div[3]/a/span[1]')
        # except:
        #     more_text_in_store = driver.find_element_by_xpath('//*[@id="mArticle"]/div[8]/div[3]/a/span[1]')
        # else:
        #     more_text_in_store = driver.find_element_by_xpath('//*[@id="mArticle"]/div[6]/div[3]/a/span[1]')
        actions = ActionChains(driver)#스크롤내리기
        actions.move_to_element(more_text_in_store).perform()
        more_text_in_store.click()
        time.sleep(0.5)
    else:
        break
    more_text_num -= 1



    #continue
    # try 구문에서 오류 발생된 경우 다음 페이지로 이동 
    # 리뷰의 1페이지 정보를 df에 저장
rate_list =[]
review_list =[]

html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
soup = BeautifulSoup(html, 'html.parser')
try:        
    store_name = soup.find(name = 'h2', attrs = {'class':'tit_location'})#가게이름
    addr = soup.find(name = 'span', attrs = {'class':'txt_address'})#가게주소
    store_operate_day = soup.find(name = 'span', attrs = {'class':'txt_operation'})#영업일 및 영업시간

    
    img_urls = soup.find(name='span', attrs={'class':'bg_present'})
    img_urls = img_urls.get('style')
    start_idx = img_urls.find('url(') + 4  # "url(" 다음 인덱스부터 시작
    end_idx = img_urls.find(')', start_idx)
    url = img_urls[start_idx:end_idx]
    

    total_strong = soup.find(name="strong", attrs={"class": "total_evaluation"})
    tot_num = total_strong.find(name="span", attrs={"class": "color_b"}) # 등록된 리뷰 갯수
    contents_div = soup.find(name='div', attrs={"class": "evaluation_review"}) #리뷰 영역. 별점, 내용
    reviewer_average_score = contents_div.find_all(name="span", attrs={"class": "txt_desc"})#리뷰어의 평균평점
    #reviewer_num = soup.find(name="span", attrs={"class": "text_desc"})#리뷰어의 평균평점
    rates=contents_div.find_all(name="span", attrs={"class": "ico_star star_rate"}) # 별점값 목록
    reviews = contents_div.find_all(name="p", attrs={"class": "txt_comment"}) # 리뷰 목록
except:
    pass
    #continue
    # try 구문에서 오류 발생된 경우 다음 페이지로 이동 
#     # 리뷰의 1페이지 정보를 df에 저장

rate_list =[]
review_list =[]
reviewer_average_score_list = []
reviewer_num_list = []

# for i in range(reviewer_average_score):
#     reviewer_average_score_list.append(reviewer_average_score)
    
for i in range(len(rates)):
    rate_value = rates[i].find(name='span', attrs={"class": "ico_star"})
    style_value = rate_value.get('style')
    if style_value == 'width:20%;':
        rate = 1
    elif style_value == 'width:40%;':
        rate = 2
    elif style_value == 'width:60%;':
        rate = 3
    elif style_value == 'width:80%;':
        rate = 4
    elif style_value == 'width:100%;':
        rate = 5
    rate_list.append(rate)    
for review in reviews:
    rev_span = review.find(name="span")
    if rev_span is not None and rev_span.text:
        rev = rev_span.text
    else:
        rev = ''
    review_list.append(rev)
for i in range(len(reviewer_average_score)):
    if i%2 == 0:
        reviewer_average_score_list.append(i.text)
    else:
        reviewer_num_list.append(i.text)

store_name = store_name.text
addr = addr.text
addr = [i.strip() for i in addr.split('\n')]
addr = ' '.join(addr)
store_operate_day = store_operate_day.text
store_operate_day = store_operate_day.replace('\n', '')

#이미지 url 추가하기


df['리뷰'] = review_list
df['별점'] = rate_list
df['리뷰자 평균 평점'] = reviewer_average_score_list
df['리뷰자 누적 리뷰 개수'] = reviewer_num_list
df['영업 시간'] = store_operate_day
df['이미지url'] = url
df['가게명'] = store_name
df['가게 주소'] = addr
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 110
#     108 for i in range(len(reviewer_average_score)):
#     109     if i%2 == 0:
# --> 110         reviewer_average_score_list.append(i.text)
#     111     else:
#     112         reviewer_num_list.append(i.text)
#
# AttributeError: 'int' object has no attribute 'text'

# %% [markdown]
# ---
# # 반복문으로 돌리기
# - 리뷰 없으면 continue
# ---

# %%
path = 'C:/chromedriver_win32/chromedriver.exe'
total_df = pd.DataFrame(columns=['리뷰','별점', '리뷰자 평균 평점','리뷰자 누적 리뷰 개수', '영업 시간','이미지url','가게명','가게 주소']) # 컬럼만 조회
driver = webdriver.Chrome(path) # 브라우저 실행
for i in page_urls:
    df = pd.DataFrame()
    time.sleep(1)
    # for page in page_urls:
    driver.get(i) # 식당 데이터 상세화면
    time.sleep(2) # 2초 쉬기
    html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
    soup = BeautifulSoup(html, 'html.parser')
    total_strong = soup.find(name="strong", attrs={"class": "total_evaluation"})
    try:
        tot_num = total_strong.find(name="span", attrs={"class": "color_b"}) # 등록된 리뷰 갯수
    except:
        pass
        # continue
    if int(tot_num.text) == 0:
        pass
        # continue
    more_text_num= ((int(tot_num.text)-3)//5)
    time.sleep(1)
    while True:
        if more_text_num >3:
            # try:
            more_text_in_store = driver.find_element_by_css_selector('span.txt_more')
                # more_text_in_store = driver.find_element_by_xpath('//*[@id="mArticle"]/div[7]/div[3]/a/span[1]')
            # except:
            #     more_text_in_store = driver.find_element_by_xpath('//*[@id="mArticle"]/div[8]/div[3]/a/span[1]')
            # else:
            #     more_text_in_store = driver.find_element_by_xpath('//*[@id="mArticle"]/div[6]/div[3]/a/span[1]')
            actions = ActionChains(driver)#스크롤내리기
            actions.move_to_element(more_text_in_store).perform()
            more_text_in_store.click()
            time.sleep(0.5)
        else:
            break
        more_text_num -= 1



        #continue
        # try 구문에서 오류 발생된 경우 다음 페이지로 이동 
        # 리뷰의 1페이지 정보를 df에 저장


    html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
    soup = BeautifulSoup(html, 'html.parser')
    try:        
        store_name = soup.find(name = 'h2', attrs = {'class':'tit_location'})#가게이름
        addr = soup.find(name = 'span', attrs = {'class':'txt_address'})#가게주소
        store_operate_day = soup.find(name = 'span', attrs = {'class':'txt_operation'})#영업일 및 영업시간

        
        img_urls = soup.find(name='span', attrs={'class':'bg_present'})
        img_urls = img_urls.get('style')
        start_idx = img_urls.find('url(') + 4  # "url(" 다음 인덱스부터 시작
        end_idx = img_urls.find(')', start_idx)
        url = img_urls[start_idx:end_idx]
        

        total_strong = soup.find(name="strong", attrs={"class": "total_evaluation"})
        tot_num = total_strong.find(name="span", attrs={"class": "color_b"}) # 등록된 리뷰 갯수
        contents_div = soup.find(name='div', attrs={"class": "evaluation_review"}) #리뷰 영역. 별점, 내용
        reviewer_average_score = contents_div.find_all(name="span", attrs={"class": "txt_desc"})#리뷰어의 평균평점
        #reviewer_num = soup.find(name="span", attrs={"class": "text_desc"})#리뷰어의 평균평점
        rates=contents_div.find_all(name="span", attrs={"class": "ico_star star_rate"}) # 별점값 목록
        reviews = contents_div.find_all(name="p", attrs={"class": "txt_comment"}) # 리뷰 목록
    except:
        pass
        #continue
        # try 구문에서 오류 발생된 경우 다음 페이지로 이동 
    #     # 리뷰의 1페이지 정보를 df에 저장

    rate_list =[]
    review_list =[]
    reviewer_average_score_list = []
    reviewer_num_list = []


    for i in range(len(rates)):
        rate_value = rates[i].find(name='span', attrs={"class": "ico_star"})
        style_value = rate_value.get('style')
        if style_value == 'width:20%;':
            rate = 1
        elif style_value == 'width:40%;':
            rate = 2
        elif style_value == 'width:60%;':
            rate = 3
        elif style_value == 'width:80%;':
            rate = 4
        elif style_value == 'width:100%;':
            rate = 5
        rate_list.append(rate)    
    for review in reviews:
        rev_span = review.find(name="span")
        if rev_span is not None and rev_span.text:
            rev = rev_span.text
        else:
            rev = ''
        review_list.append(rev)
    for i in range(len(reviewer_average_score)):
        if i%2 == 0:
            reviewer_average_score_list.append(reviewer_average_score[i].text)
        else:
            reviewer_num_list.append(reviewer_average_score[i].text)

    store_name = store_name.text
    addr = addr.text
    addr = [i.strip() for i in addr.split('\n')]
    addr = ' '.join(addr)
    store_operate_day = store_operate_day.text
    store_operate_day = store_operate_day.replace('\n', '')

    #이미지 url 추가하기

    df['리뷰'] = review_list
    df['별점'] = rate_list
    df['리뷰자 평균 평점'] = reviewer_average_score_list
    df['리뷰자 누적 리뷰 개수'] = reviewer_num_list
    df['영업 시간'] = store_operate_day
    df['이미지url'] = url
    df['가게명'] = store_name
    df['가게 주소'] = addr
    print(df)
    total_df = pd.concat([total_df,df])
# Out:
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    칼국수는 별로였지만 김치가 존맛이어서 김치 먹으려규 칼국수 먹었음 김치에 마늘향이 ...   4        10
# 1                                          바퀴벌레 국수 맛존탱   1        11
# 2                                                        5        27
# 3                                                        5        38
# 4    시간지나면 생각나는 맛.부들부들한 면.. 맛=평타침자리는 많지만 테이블 협소, 웨이...   4       138
# ..                                                 ...  ..       ...
# 933  언제나맛있는곳. 꼬들꼬들한 밥도 칼국수를남기더라도 한입먹어야 함. 김치도맛나구ㅠ.ㅠ...   4        85
# 934                    명동교자보단 베테랑 칼국수가 내스타일인듯. 만두는 맛있음   3        88
# 935  별점 기준1) 재방문 의사 없음.2) 찾아서 갈만큼은 아님. 주로 가성비 떨어짐.3...   4       163
# 936                        칼국수, 만두는 맛있으나비빔국수는 그저 그런 정도   3       195
# 937  오빠랑 배고파서 가자마자 주문이후 10분만에 싹쓸이진짜 맛있어!!!!♥︎ Love ...   5     1,464
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            3.6  매일 10:30 ~ 21:30
# 1            4.2  매일 10:30 ~ 21:30
# 2            5.0  매일 10:30 ~ 21:30
# 3            4.8  매일 10:30 ~ 21:30
# 4            4.0  매일 10:30 ~ 21:30
# ..           ...               ...
# 933          3.6  매일 10:30 ~ 21:30
# 934          4.2  매일 10:30 ~ 21:30
# 935          2.7  매일 10:30 ~ 21:30
# 936          3.6  매일 10:30 ~ 21:30
# 937          3.9  매일 10:30 ~ 21:30
#
#                                                 이미지url      가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
# ..                                                 ...      ...
# 933  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
# 934  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
# 935  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
# 936  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
# 937  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  명동교자 본점
#
#                        가게 주소
# 0    서울 중구 명동10길 29 (우)04537
# 1    서울 중구 명동10길 29 (우)04537
# 2    서울 중구 명동10길 29 (우)04537
# 3    서울 중구 명동10길 29 (우)04537
# 4    서울 중구 명동10길 29 (우)04537
# ..                       ...
# 933  서울 중구 명동10길 29 (우)04537
# 934  서울 중구 명동10길 29 (우)04537
# 935  서울 중구 명동10길 29 (우)04537
# 936  서울 중구 명동10길 29 (우)04537
# 937  서울 중구 명동10길 29 (우)04537
#
# [938 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    기다려서 사갈 정도는 아니나 안국와서 유명한 집 들른다는 맘으로 들렀습니다 건대점이...   3        13
# 1    분위기는 좋은데 애들 소리치고 뛰어다니고 울고불고 자갈던지고 노는건 직원이 관리를 ...   3        76
# 2    빵을 발 밑에 보관하고 원두도 오래된 맛.회전율이 이렇게 좋은데 커피가 이렇게 맛없...   1         1
# 3                                                        4        38
# 4    사람은 진짜 많은데 빵 가성비잇고 맛있어요 직원분들도 넘넘 친절하세여!! 설날에 갔...   5         8
# ..                                                 ...  ..       ...
# 203  커피 괜찮고 외관 괜찮은데 내부는 다닥다닥 붙어있는 밥집만 못해요. 전면이 유리인데...   1        43
# 204  분위기는 참 좋았으나의자 엄청 딱딱하고 불편합니다방도 다과상은 낮고 더불편할듯!!커...   1         2
# 205                  Einspanner, 초코라 and 팡도르.9시처럼 일찍와.   3        19
# 206  워낙 많이 들어서 왔는데 빵진열도 사람들 다니는곳에 오픈한채로 두고 고르게 되어있네...   1        11
# 207  이쁘고 다 좋은데 주문이 너무너무너무너무 오래걸림. 사람이 그리 많은데 주문 받는사...   1         2
#
#     리뷰자 누적 리뷰 개수              영업 시간  \
# 0            4.3  토,일 09:00 ~ 22:00
# 1            3.3  토,일 09:00 ~ 22:00
# 2            1.0  토,일 09:00 ~ 22:00
# 3            4.7  토,일 09:00 ~ 22:00
# 4            4.6  토,일 09:00 ~ 22:00
# ..           ...                ...
# 203          3.9  토,일 09:00 ~ 22:00
# 204          1.5  토,일 09:00 ~ 22:00
# 205          3.9  토,일 09:00 ~ 22:00
# 206          1.8  토,일 09:00 ~ 22:00
# 207          1.0  토,일 09:00 ~ 22:00
#
#                                                 이미지url      가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
# ..                                                 ...      ...
# 203  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
# 204  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
# 205  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
# 206  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
# 207  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  어니언 안국점
#
#                      가게 주소
# 0    서울 종로구 계동길 5 (우)03059
# 1    서울 종로구 계동길 5 (우)03059
# 2    서울 종로구 계동길 5 (우)03059
# 3    서울 종로구 계동길 5 (우)03059
# 4    서울 종로구 계동길 5 (우)03059
# ..                     ...
# 203  서울 종로구 계동길 5 (우)03059
# 204  서울 종로구 계동길 5 (우)03059
# 205  서울 종로구 계동길 5 (우)03059
# 206  서울 종로구 계동길 5 (우)03059
# 207  서울 종로구 계동길 5 (우)03059
#
# [208 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0                          직원들 너무 불친절해요. 도넛 맛도 그냥 그래요~   1        11
# 1    별점 3.5-맛은 괜찮음, 종류 꽤 다양함.-분위기 깜찍함-기다리는 게 너무너무너무...   3        41
# 2                                       맛있어용 근데 자리가 불편   4        98
# 3                                                        4        80
# 4                 노티드 케이크는 가볍게 선물하기 좋은것같아요받는사람도 좋아하구요.   5        14
# ..                                                 ...  ..       ...
# 213  너무 불친절함!! 장사 잘된다고 손님 이런식으로 응대하면 안됨 테이크아웃 줄서라고 ...   1         2
# 214  기본이 안된 점포. 11시 오픈인데 20분 넘도록 안내도 없고 뭘 물어봐도 무조건 ...   1         4
# 215  There were no signs saying what your covid rul...   1         1
# 216         두번갔었는데 두번 다 얼그레이는 솔드아웃이네요. 다음에 갔을 땐 있겠죠..?   3        18
# 217                                                      4       117
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            3.4  매일 10:00 ~ 21:00
# 1            4.0  매일 10:00 ~ 21:00
# 2            4.1  매일 10:00 ~ 21:00
# 3            3.9  매일 10:00 ~ 21:00
# 4            4.3  매일 10:00 ~ 21:00
# ..           ...               ...
# 213          1.0  매일 10:00 ~ 21:00
# 214          1.0  매일 10:00 ~ 21:00
# 215          1.0  매일 10:00 ~ 21:00
# 216          3.6  매일 10:00 ~ 21:00
# 217          3.7  매일 10:00 ~ 21:00
#
#                                                 이미지url     가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
# ..                                                 ...     ...
# 213  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
# 214  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
# 215  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
# 216  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
# 217  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 안국
#
#                           가게 주소
# 0    서울 종로구 북촌로 6-3 1층 (우)03059
# 1    서울 종로구 북촌로 6-3 1층 (우)03059
# 2    서울 종로구 북촌로 6-3 1층 (우)03059
# 3    서울 종로구 북촌로 6-3 1층 (우)03059
# 4    서울 종로구 북촌로 6-3 1층 (우)03059
# ..                          ...
# 213  서울 종로구 북촌로 6-3 1층 (우)03059
# 214  서울 종로구 북촌로 6-3 1층 (우)03059
# 215  서울 종로구 북촌로 6-3 1층 (우)03059
# 216  서울 종로구 북촌로 6-3 1층 (우)03059
# 217  서울 종로구 북촌로 6-3 1층 (우)03059
#
# [218 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    평양냉면은 쏘쏘, 제육이랑 편육 중에 고르라면 제육! 편육은 우리가 아는 딱딱한 편...   4        44
# 1                                                 맛있어요   4         2
# 2                                          올려치기 정도껏 해라   1        54
# 3                                       뜨끈하니 한끼 하기 좋네요   5       247
# 4    평냉 최고존엄입니다처음에는 순정의 맛을 즐기다가그다음 고춧가루를 조금 풀어보시면 미...   5       485
# ..                                                 ...  ..       ...
# 273         의정부가 멀어 못 가는 이에게 이 만한 곳은 없다 육수 리필도 통 크게 준다   5       863
# 274                         서북면옥에서 받은 상처를 치유받다.제육이 맛있다   3       611
# 275      저녁엔 다들 수육전골에 술상파티~ 냉면 먹으로 낮에만 다녔는데 전골도 괜찮나바요.   4       131
# 276                                                      3       413
# 277                                     평냉집들은 언제나 옳다.!   4        66
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            4.0  매일 11:00 ~ 21:30
# 1            2.5  매일 11:00 ~ 21:30
# 2            2.7  매일 11:00 ~ 21:30
# 3            4.7  매일 11:00 ~ 21:30
# 4            3.7  매일 11:00 ~ 21:30
# ..           ...               ...
# 273          4.2  매일 11:00 ~ 21:30
# 274          3.1  매일 11:00 ~ 21:30
# 275          3.4  매일 11:00 ~ 21:30
# 276          3.5  매일 11:00 ~ 21:30
# 277          3.6  매일 11:00 ~ 21:30
#
#                                                 이미지url     가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
# ..                                                 ...     ...
# 273  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
# 274  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
# 275  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
# 276  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
# 277  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진미평양냉면
#
#                                  가게 주소
# 0    서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
# 1    서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
# 2    서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
# 3    서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
# 4    서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
# ..                                 ...
# 273  서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
# 274  서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
# 275  서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
# 276  서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
# 277  서울 강남구 학동로 305-3 정각빌딩 1층 (우)06061
#
# [278 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0                                                        3        31
# 1    맛 3양 1친절 4돈값 못함주차 불가2시간 넘게 기다려서 주린 배를 움켜쥐고 먹는걸...   1       595
# 2    웨이팅 30팀 기다릴 정도의 고기 맛은 아니였어요. 그냥 평범한 돼지고기.. 여길 ...   3       145
# 3     맛있지만 내 돈주고는 가기엔 비싸서 좀 꺼려지는 집남이 사준다면 두 발 벗고 달려갑니다   4        21
# 4                         맛있기는 한데 줄서서 먹을 정도는 아닌 것 같아요.   5         9
# ..                                                 ...  ..       ...
# 243                          서비스 친절하고 좋음삼겹보단 목살이 더 맛있음   4        48
# 244                                                      3       121
# 245    최악이다. 고기는 맛있다. 근데 맛있다라는 장점을 무색하게 할만큼 서비스가 개판이다.   1        63
# 246                                                      4       714
# 247  豚キムチチゲがおいしくおススメ！サムギョプサルはそれ程ジューシーではありませんが、1人前は1...   4       156
#
#     리뷰자 누적 리뷰 개수                                              영업 시간  \
# 0            4.1  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
# 1            3.7  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
# 2            4.6  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
# 3            4.0  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
# 4            4.3  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
# ..           ...                                                ...
# 243          3.4  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
# 244          3.4  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
# 245          3.0  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
# 246          4.1  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
# 247          4.3  매일 11:30 ~ 23:00(1층 마감시간 23:00 / 2,3층 마감시간 22:00)
#
#                                                 이미지url    가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
# ..                                                 ...    ...
# 243  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
# 244  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
# 245  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
# 246  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
# 247  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  금돼지식당
#
#                            가게 주소
# 0    서울 중구 다산로 149 1~3층 (우)04607
# 1    서울 중구 다산로 149 1~3층 (우)04607
# 2    서울 중구 다산로 149 1~3층 (우)04607
# 3    서울 중구 다산로 149 1~3층 (우)04607
# 4    서울 중구 다산로 149 1~3층 (우)04607
# ..                           ...
# 243  서울 중구 다산로 149 1~3층 (우)04607
# 244  서울 중구 다산로 149 1~3층 (우)04607
# 245  서울 중구 다산로 149 1~3층 (우)04607
# 246  서울 중구 다산로 149 1~3층 (우)04607
# 247  서울 중구 다산로 149 1~3층 (우)04607
#
# [248 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0                                                        3         4
# 1    유명세로 한번쯤 가볼만한곳 인테리어가 과하고 부담될정도로 귀여워요ㅋㅋ의외로 테이블 ...   4         8
# 2    망고맛 크림이 들어있는 케이크!안에 망고 슬라이스나 망고 과육은 없음! 하지만 크림...   5       245
# 3                                          구매하고 바로 드시길   4        67
# 4                                               맛있는 도넛   5         9
# ..                                                 ...  ..       ...
# 293                      줄서서먹을곳아님. 오더틀리고 매우불만족. 가성비최악.   1        27
# 294                                                      3       353
# 295  비싼 시장도넛이라는 말이 딱이라는 생각이 드네요사람마다 다르겠지만 전 그렇게 맛있는...   1       270
# 296   가성비 글쎄요빵은 맛있었어요조금 비싸지만~발렛두 비싸비싸...3000원이면 빵하나값 ㅋ   3         3
# 297                                                      4     1,015
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            4.0  매일 09:00 ~ 21:00
# 1            4.0  매일 09:00 ~ 21:00
# 2            3.7  매일 09:00 ~ 21:00
# 3            3.8  매일 09:00 ~ 21:00
# 4            4.8  매일 09:00 ~ 21:00
# ..           ...               ...
# 293          1.3  매일 09:00 ~ 21:00
# 294          3.2  매일 09:00 ~ 21:00
# 295          3.5  매일 09:00 ~ 21:00
# 296          4.3  매일 09:00 ~ 21:00
# 297          4.0  매일 09:00 ~ 21:00
#
#                                                 이미지url     가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
# ..                                                 ...     ...
# 293  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
# 294  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
# 295  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
# 296  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
# 297  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  노티드 청담
#
#                              가게 주소
# 0    서울 강남구 도산대로53길 15 1층 (우)06019
# 1    서울 강남구 도산대로53길 15 1층 (우)06019
# 2    서울 강남구 도산대로53길 15 1층 (우)06019
# 3    서울 강남구 도산대로53길 15 1층 (우)06019
# 4    서울 강남구 도산대로53길 15 1층 (우)06019
# ..                             ...
# 293  서울 강남구 도산대로53길 15 1층 (우)06019
# 294  서울 강남구 도산대로53길 15 1층 (우)06019
# 295  서울 강남구 도산대로53길 15 1층 (우)06019
# 296  서울 강남구 도산대로53길 15 1층 (우)06019
# 297  서울 강남구 도산대로53길 15 1층 (우)06019
#
# [298 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    처음,두번째까진 찐 맛집이었다어느순간 곱창 양이 줄면서..속이안좋거나 무튼..다음날...   3         7
# 1                                                        5        53
# 2                    맛집이 맞긴한가봐요 아저씨들이 술마시면서 정치 이야기 하네요   5        14
# 3                                                        5         1
# 4                                내장탕 맛집. 전골은 한번은 먹을만함.   4        25
# ..                                                 ...  ..       ...
# 398                                                      4       117
# 399   양 선지해장국 진짜 많다 맛있기도 하고~~밥 한톨도 못 먹었음 그 정도로 양이 어마어마   5       863
# 400                                       국물먹고 싶을때 좋아요   4       224
# 401                                                      3     1,044
# 402                                               곱창전골   3       459
#
#     리뷰자 누적 리뷰 개수            영업 시간  \
# 0            4.7  일 07:00 ~ 21:30
# 1            3.7  일 07:00 ~ 21:30
# 2            2.9  일 07:00 ~ 21:30
# 3            5.0  일 07:00 ~ 21:30
# 4            3.1  일 07:00 ~ 21:30
# ..           ...              ...
# 398          3.9  일 07:00 ~ 21:30
# 399          4.2  일 07:00 ~ 21:30
# 400          3.1  일 07:00 ~ 21:30
# 401          3.0  일 07:00 ~ 21:30
# 402          3.2  일 07:00 ~ 21:30
#
#                                                 이미지url   가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
# ..                                                 ...   ...
# 398  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
# 399  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
# 400  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
# 401  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
# 402  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  중앙해장
#
#                                   가게 주소
# 0    서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
# 1    서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
# 2    서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
# 3    서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
# 4    서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
# ..                                  ...
# 398  서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
# 399  서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
# 400  서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
# 401  서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
# 402  서울 강남구 영동대로86길 17 육인빌딩 1층 (우)06174
#
# [403 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    다 먹지도 않았는데 조선족 직원들이 와서 중국말로 뭐라하고 마감시간 다가오니 나가라...   1         1
# 1                                                        5        19
# 2    맛은 있으나 이 정도로 인기가 있을만한가?는 의구심은 있습니다. 맛있게 먹었으나 재...   4        65
# 3                                           수제비 국물 맛있음   5         1
# 4                            위생 별로 친절 별로맛은 좋음 재방문의사 있음   4        31
# ..                                                 ...  ..       ...
# 323                                                      4       407
# 324                       수제비가 얇아서 그야말로 호로록 가능함. 맛있어요.   3       104
# 325                      수제비. 항상 사람이 많아서 좀처럼 먹기가 힘들다..   3       459
# 326                                                      4       105
# 327                 옛날에 먹을 거 없었을 때나.지금은 그런 추억으로 먹는 음식.   2       536
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            1.0  매일 11:00 ~ 20:30
# 1            3.9  매일 11:00 ~ 20:30
# 2            3.6  매일 11:00 ~ 20:30
# 3            5.0  매일 11:00 ~ 20:30
# 4            4.2  매일 11:00 ~ 20:30
# ..           ...               ...
# 323          3.7  매일 11:00 ~ 20:30
# 324          3.4  매일 11:00 ~ 20:30
# 325          3.2  매일 11:00 ~ 20:30
# 326          4.0  매일 11:00 ~ 20:30
# 327          2.6  매일 11:00 ~ 20:30
#
#                                                 이미지url     가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
# ..                                                 ...     ...
# 323  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
# 324  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
# 325  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
# 326  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
# 327  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼청동수제비
#
#                          가게 주소
# 0    서울 종로구 삼청로 101-1 (우)03049
# 1    서울 종로구 삼청로 101-1 (우)03049
# 2    서울 종로구 삼청로 101-1 (우)03049
# 3    서울 종로구 삼청로 101-1 (우)03049
# 4    서울 종로구 삼청로 101-1 (우)03049
# ..                         ...
# 323  서울 종로구 삼청로 101-1 (우)03049
# 324  서울 종로구 삼청로 101-1 (우)03049
# 325  서울 종로구 삼청로 101-1 (우)03049
# 326  서울 종로구 삼청로 101-1 (우)03049
# 327  서울 종로구 삼청로 101-1 (우)03049
#
# [328 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    요즘 커피맛좋은데 많아서 맛은 호불호라고 할게요갠적으론 특별하단건 못느껴서주차안됌가...   1         1
# 1                                  그냥 빠르게 뽑아내는 그저그런 커피   2        38
# 2    적당히 친절한데 매장 관리가 그렇게 잘 되는 것 같진 않았습니다 빈 탁자를 스스로 ...   3       351
# 3                            사람 너무 많음 맛은 확실히 있음 하지만 비쌈   4         8
# 4                                       오트밀크 아이스 라떼 맛집   5        22
# ..                                                 ...  ..       ...
# 178                     한번가고 말듯요...딱 인스타용 그이상 그이하도 아닌곳   3        72
# 179  라떼를 평소 즐겨 마시는데 아이스 라떼는 균형있고 향이 좋다고 생각했어요. 워낙 오...   5        26
# 180  요즘엔 음식점 내부가 이 모양이어도 장사가 가능한가봄..신기하네..싼 폐건물 사가지...   1       320
# 181  그렇게 유명하다길래 1시간 넘게 서서 갔다왔는데인스타충이면 가는거 추천커피 주시는 ...   1        23
# 182  멀쩡한 1층에 로스터리실과 바닥을 파서 중정을 내었다. 사람들은 막만든 인더스트리얼...   5        28
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            1.0  매일 08:00 ~ 20:00
# 1            3.3  매일 08:00 ~ 20:00
# 2            4.3  매일 08:00 ~ 20:00
# 3            4.4  매일 08:00 ~ 20:00
# 4            3.8  매일 08:00 ~ 20:00
# ..           ...               ...
# 178          3.4  매일 08:00 ~ 20:00
# 179          4.3  매일 08:00 ~ 20:00
# 180          3.4  매일 08:00 ~ 20:00
# 181          3.7  매일 08:00 ~ 20:00
# 182          4.0  매일 08:00 ~ 20:00
#
#                                                 이미지url         가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
# ..                                                 ...         ...
# 178  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
# 179  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
# 180  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
# 181  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
# 182  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  블루보틀 성수 카페
#
#                       가게 주소
# 0    서울 성동구 아차산로 7 (우)04789
# 1    서울 성동구 아차산로 7 (우)04789
# 2    서울 성동구 아차산로 7 (우)04789
# 3    서울 성동구 아차산로 7 (우)04789
# 4    서울 성동구 아차산로 7 (우)04789
# ..                      ...
# 178  서울 성동구 아차산로 7 (우)04789
# 179  서울 성동구 아차산로 7 (우)04789
# 180  서울 성동구 아차산로 7 (우)04789
# 181  서울 성동구 아차산로 7 (우)04789
# 182  서울 성동구 아차산로 7 (우)04789
#
# [183 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    어제 10년만에 세종문화회관 공연보기전에 옛맛을 기억하고 찾았는데아주머니는 주문 을...   2         1
# 1    글쎄. 문현시장안 허름한 소피국이 더 좋았다. 입맛은 변한다. 그 시절의 그 맛은 ...   2         1
# 2                                                        4       314
# 3                                                        5        35
# 4    서울식 선지해장국의 원조, 가격에 비해 내용물은 평범하지만 한우라 감안할만함. 국물...   4       111
# ..                                                 ...  ..       ...
# 178  맛은 담백하고 좋습니다만 서빙이 너무 아쉽습니다.  늦게 온 손님은 5분만에 나오는...   1        23
# 179                                                      4        94
# 180                                                      3     1,006
# 181  3대를 이어 내려온 선지해장국 노하우가 그대로 녹아있는 느낌.. 속이 편안하게 풀리는 맛   4         2
# 182                                                      4        21
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            2.0  매일 06:00 ~ 22:00
# 1            2.0  매일 06:00 ~ 22:00
# 2            3.1  매일 06:00 ~ 22:00
# 3            5.0  매일 06:00 ~ 22:00
# 4            4.3  매일 06:00 ~ 22:00
# ..           ...               ...
# 178          3.3  매일 06:00 ~ 22:00
# 179          3.9  매일 06:00 ~ 22:00
# 180          3.0  매일 06:00 ~ 22:00
# 181          2.5  매일 06:00 ~ 22:00
# 182          4.3  매일 06:00 ~ 22:00
#
#                                                 이미지url  가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
# ..                                                 ...  ...
# 178  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
# 179  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
# 180  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
# 181  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
# 182  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청진옥
#
#                        가게 주소
# 0    서울 종로구 종로3길 32 (우)03156
# 1    서울 종로구 종로3길 32 (우)03156
# 2    서울 종로구 종로3길 32 (우)03156
# 3    서울 종로구 종로3길 32 (우)03156
# 4    서울 종로구 종로3길 32 (우)03156
# ..                       ...
# 178  서울 종로구 종로3길 32 (우)03156
# 179  서울 종로구 종로3길 32 (우)03156
# 180  서울 종로구 종로3길 32 (우)03156
# 181  서울 종로구 종로3길 32 (우)03156
# 182  서울 종로구 종로3길 32 (우)03156
#
# [183 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0                                               우대갈비 굿   3        74
# 1                                                        5         8
# 2    음식이 너무 달아요. 이 사장 업장 특징인듯.그리고 웨이팅을 일부러 손님친화적시스템...   1        34
# 3                           웨이팅이 있지만 맛은 보장 가격은 비싼편입니다.   5         2
# 4    평일 오전 11시5분에 도착해서 바로 이름 적었는데 12시반 타임이었구요둘이 가서 ...   5        27
# ..                                                 ...  ..       ...
# 358  웨이팅이 지나치게 긴건 알고 갔으니 상관 없었으나 대기 공간에 해당 손님이 있는지 ...   1        11
# 359  자리가  창가였는데 먹다가 너무추워서 감기만 걸려서 옴 그렇게 오래 기다려서 먹을맛...   1       114
# 360  웨이팅이 긴 곳이라 오늘 맘먹고 처음 가봤는데, 일찍 가서인지 다행이 웨이팅없이 착...   5        10
# 361                                                      4        82
# 362                                                      4       195
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            4.3  매일 12:00 ~ 22:00
# 1            4.6  매일 12:00 ~ 22:00
# 2            1.7  매일 12:00 ~ 22:00
# 3            5.0  매일 12:00 ~ 22:00
# 4            2.7  매일 12:00 ~ 22:00
# ..           ...               ...
# 358          3.1  매일 12:00 ~ 22:00
# 359          3.8  매일 12:00 ~ 22:00
# 360          5.0  매일 12:00 ~ 22:00
# 361          3.8  매일 12:00 ~ 22:00
# 362          3.9  매일 12:00 ~ 22:00
#
#                                                 이미지url 가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
# ..                                                 ...  ..
# 358  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
# 359  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
# 360  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
# 361  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
# 362  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  몽탄
#
#                               가게 주소
# 0    서울 용산구 백범로99길 50 1,2층 (우)04375
# 1    서울 용산구 백범로99길 50 1,2층 (우)04375
# 2    서울 용산구 백범로99길 50 1,2층 (우)04375
# 3    서울 용산구 백범로99길 50 1,2층 (우)04375
# 4    서울 용산구 백범로99길 50 1,2층 (우)04375
# ..                              ...
# 358  서울 용산구 백범로99길 50 1,2층 (우)04375
# 359  서울 용산구 백범로99길 50 1,2층 (우)04375
# 360  서울 용산구 백범로99길 50 1,2층 (우)04375
# 361  서울 용산구 백범로99길 50 1,2층 (우)04375
# 362  서울 용산구 백범로99길 50 1,2층 (우)04375
#
# [363 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    맛은 있어요 가격도 괜찮고 웨이팅 걸어두고 놀다오면 돼요그런데 먹다가 머리카락 나와...   2        15
# 1    예쁘게 해놔서 분위기는 좋습니다만 순대국이 깔끔하지 않고 기름기 많은 맛입니다. 추...   2         2
# 2    빈자리가 득실득실한데 손님들 대기하게 만드는곳.직원들얼굴에 나 일하기싫어~~가 쓰여...   1         4
# 3                            흔한 sns 광고 맛집입니다. 프랜차이즈 맛임   3        22
# 4                                                        5         3
# ..                                                 ...  ..       ...
# 168  음식이 전체적으로 깔끔하고 좋아요순대국 육회 오징어 숯불 구이 먹었는데 식욕을 부르...   5         1
# 169  순대국 마니아로써 너무 괜찮았어요.음식도 정갈하고 깔끔한 분위기가 너무 좋았어요. ...   5         3
# 170  양도 맘에 들고, 무엇보다 깔끔한 맛이 아주 맘에 듭니다.  집근처에 있으면 자주 ...   5         2
# 171         맛있어요 ㅎㅎ 청와옥 석촌, 방이 자주 가요. 순대는 넘나 제 스타일 >_<   5         4
# 172  순대국 정말 좋아하는데 다양한 맛 선택도 가능하고 사이드 메뉴들까지 완전 맛있고 저...   5         2
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            3.9  매일 08:00 ~ 22:00
# 1            3.5  매일 08:00 ~ 22:00
# 2            1.0  매일 08:00 ~ 22:00
# 3            3.3  매일 08:00 ~ 22:00
# 4            3.7  매일 08:00 ~ 22:00
# ..           ...               ...
# 168          5.0  매일 08:00 ~ 22:00
# 169          5.0  매일 08:00 ~ 22:00
# 170          5.0  매일 08:00 ~ 22:00
# 171          5.0  매일 08:00 ~ 22:00
# 172          5.0  매일 08:00 ~ 22:00
#
#                                                 이미지url     가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
# ..                                                 ...     ...
# 168  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
# 169  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
# 170  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
# 171  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
# 172  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청와옥 본점
#
#                                      가게 주소
# 0    서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
# 1    서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
# 2    서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
# 3    서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
# 4    서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
# ..                                     ...
# 168  서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
# 169  서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
# 170  서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
# 171  서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
# 172  서울 송파구 위례성대로 48 반도빌딩 1층 102호 (우)05627
#
# [173 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    망빙은 맛있었는데 재방문때 맛이 떨어져서 원물차이가 있으니 넘어갈 수 있지만 김볶이...   3        38
# 1    여자친구랑 1주년 기념으로 왔어요! 주류는 가격대가 조금 있지만 다른 메뉴들은 리즈...   5        24
# 2                       무려 만구천원짜리 김뽁 ,,,, 하타보다 맛있는듯 ㅋㅋ   4         5
# 3    누나가 몇일전 엄마랑가서 맥주한잔에 떡볶이먹고 5만얼마 나왔다고 해서 어딘가 했더니...   2       104
# 4                 ㅋㅋㅋㅋㅋㅋ 별놈들 보고 왔어요! 생각보다 인테리어 예뻐서 놀랐음   4        20
# ..                                                 ...  ..       ...
# 143              피자 맛은 괜찮으나.. 굳이?!? 굳이?!!!발렛이 진짜 불친절ㅋㅋ   3       193
# 144  발렛 얘기도 없이 다른 건물로 주차했다면서 3천원짜릴 2만5천원 받는 양아치 새끼들...   1         9
# 145                                                      5       126
# 146                                       맛있고 분위기도 좋아요   4        96
# 147                               일하는분들 관리가 잘 안되는것 같네요   1       102
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            4.1  매일 11:00 ~ 05:00
# 1            5.0  매일 11:00 ~ 05:00
# 2            4.8  매일 11:00 ~ 05:00
# 3            3.2  매일 11:00 ~ 05:00
# 4            5.0  매일 11:00 ~ 05:00
# ..           ...               ...
# 143          3.5  매일 11:00 ~ 05:00
# 144          2.8  매일 11:00 ~ 05:00
# 145          4.5  매일 11:00 ~ 05:00
# 146          3.3  매일 11:00 ~ 05:00
# 147          2.9  매일 11:00 ~ 05:00
#
#                                                 이미지url     가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
# ..                                                 ...     ...
# 143  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
# 144  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
# 145  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
# 146  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
# 147  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스케줄 청담
#
#                              가게 주소
# 0    서울 강남구 선릉로152길 37 1층 (우)06016
# 1    서울 강남구 선릉로152길 37 1층 (우)06016
# 2    서울 강남구 선릉로152길 37 1층 (우)06016
# 3    서울 강남구 선릉로152길 37 1층 (우)06016
# 4    서울 강남구 선릉로152길 37 1층 (우)06016
# ..                             ...
# 143  서울 강남구 선릉로152길 37 1층 (우)06016
# 144  서울 강남구 선릉로152길 37 1층 (우)06016
# 145  서울 강남구 선릉로152길 37 1층 (우)06016
# 146  서울 강남구 선릉로152길 37 1층 (우)06016
# 147  서울 강남구 선릉로152길 37 1층 (우)06016
#
# [148 rows x 8 columns]
#                                                    리뷰  별점 리뷰자 평균 평점  \
# 0                                                       5        28
# 1                                  음식 맛있고, 직원들 친절합니다.   5        12
# 2                                                       5       330
# 3                                  맛있어서 놀랐다.구워줘서 편했다.   4        16
# 4                                      맛있고 친절해요! 만족만족   5        26
# ..                                                ...  ..       ...
# 88  삼겹살이 땡기는 날에 여기 가는걸 꼭 추천드려용!!!직원들도 친절하시고 삼겹살도 직...   5         1
# 89  직원분들도 친절하시고 육즙통삼겹 먹었는데 겉은 바삭하고 속은 야들야들하면서 육즙이 ...   5         1
# 90     얼마 전에 고기 먹고 싶어서 갔는데 너무 맛있었어요!! 꽃삼겹 최고!!!!!!!!!   5         1
# 91  오랜만에 만난 친구와 방문했는데 직접 고기를 구워주셔서 대화에 집중할 수 있어 좋았...   5         1
# 92  블로그보고 방문했는데 고기구워주시는 분들이 잘 구워주시고 친절하셔서 너무 좋았어요!...   5         1
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 0           3.8  매일 11:30 ~ 23:00
# 1           4.5  매일 11:30 ~ 23:00
# 2           3.5  매일 11:30 ~ 23:00
# 3           4.1  매일 11:30 ~ 23:00
# 4           3.3  매일 11:30 ~ 23:00
# ..          ...               ...
# 88          5.0  매일 11:30 ~ 23:00
# 89          5.0  매일 11:30 ~ 23:00
# 90          5.0  매일 11:30 ~ 23:00
# 91          5.0  매일 11:30 ~ 23:00
# 92          5.0  매일 11:30 ~ 23:00
#
#                                                이미지url         가게명  \
# 0   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
# 1   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
# 2   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
# 3   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
# 4   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
# ..                                                ...         ...
# 88  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
# 89  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
# 90  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
# 91  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
# 92  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  삼육가 사당역1호점
#
#                          가게 주소
# 0   서울 서초구 방배천로 10 1층 (우)06693
# 1   서울 서초구 방배천로 10 1층 (우)06693
# 2   서울 서초구 방배천로 10 1층 (우)06693
# 3   서울 서초구 방배천로 10 1층 (우)06693
# 4   서울 서초구 방배천로 10 1층 (우)06693
# ..                         ...
# 88  서울 서초구 방배천로 10 1층 (우)06693
# 89  서울 서초구 방배천로 10 1층 (우)06693
# 90  서울 서초구 방배천로 10 1층 (우)06693
# 91  서울 서초구 방배천로 10 1층 (우)06693
# 92  서울 서초구 방배천로 10 1층 (우)06693
#
# [93 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    옛날에 다른곳에서 닭한마리 맛있게 먹었던 기억이 있어서 여기도 유명하길래 방문했는데...   2         5
# 1                                                        4         4
# 2                               국물이 진하고 늘 다시 생각나는 그 맛!   5         3
# 3                         별점 3.8-국물👍👍-가성비는 좀 떨어지는데 맛있음   4        41
# 4    주기적으로 가는 곳매장이 워낙 커서 웨이팅 아무리 많아도 30분 안에 해결됨손님 개...   4        13
# ..                                                 ...  ..       ...
# 213                                                      4       295
# 214  고기는 오래되서 질기고 냄새남.양재기에 닭만 한마리 물에 담가주면떡이고 파고 전부 ...   1         5
# 215                                                      4         4
# 216                                           외국인이 가는곳   1       225
# 217                                                      2       169
#
#     리뷰자 누적 리뷰 개수                           영업 시간  \
# 0            2.8  매일 10:30 ~ 01:00(입장마감 23:30까지)
# 1            2.8  매일 10:30 ~ 01:00(입장마감 23:30까지)
# 2            5.0  매일 10:30 ~ 01:00(입장마감 23:30까지)
# 3            4.0  매일 10:30 ~ 01:00(입장마감 23:30까지)
# 4            4.2  매일 10:30 ~ 01:00(입장마감 23:30까지)
# ..           ...                             ...
# 213          4.0  매일 10:30 ~ 01:00(입장마감 23:30까지)
# 214          1.4  매일 10:30 ~ 01:00(입장마감 23:30까지)
# 215          2.8  매일 10:30 ~ 01:00(입장마감 23:30까지)
# 216          2.9  매일 10:30 ~ 01:00(입장마감 23:30까지)
# 217          3.2  매일 10:30 ~ 01:00(입장마감 23:30까지)
#
#                                                 이미지url             가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
# ..                                                 ...             ...
# 213  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
# 214  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
# 215  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
# 216  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
# 217  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진옥화할매원조닭한마리 본점
#
#                          가게 주소
# 0    서울 종로구 종로40가길 18 (우)03197
# 1    서울 종로구 종로40가길 18 (우)03197
# 2    서울 종로구 종로40가길 18 (우)03197
# 3    서울 종로구 종로40가길 18 (우)03197
# 4    서울 종로구 종로40가길 18 (우)03197
# ..                         ...
# 213  서울 종로구 종로40가길 18 (우)03197
# 214  서울 종로구 종로40가길 18 (우)03197
# 215  서울 종로구 종로40가길 18 (우)03197
# 216  서울 종로구 종로40가길 18 (우)03197
# 217  서울 종로구 종로40가길 18 (우)03197
#
# [218 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0                가격, 어수선한 분위기, 미친 인파에도 불구하고 맛 때문에 가는 곳   4        19
# 1    포장하러 방문했는데  주차비 요금 부당청구  예전에는 안그랬는데 주인이 바뀌어서  ...   1         1
# 2                                                        4        28
# 3                                                        3       192
# 4    먹어본 평양냉면 중 최고임. 육향 진하고 면 곱배기로 추가해도 물리지않는 맛. 제일...   5        22
# ..                                                 ...  ..       ...
# 653                                                      4        92
# 654                                                      4       101
# 655                                             냉면 황광해   4     1,285
# 656                                                      3        72
# 657                                    전통평영냉면(12,000원)   4        87
#
#     리뷰자 누적 리뷰 개수              영업 시간  \
# 0            3.8  화~일 11:30 ~ 21:00
# 1            1.0  화~일 11:30 ~ 21:00
# 2            3.2  화~일 11:30 ~ 21:00
# 3            2.7  화~일 11:30 ~ 21:00
# 4            2.8  화~일 11:30 ~ 21:00
# ..           ...                ...
# 653          3.6  화~일 11:30 ~ 21:00
# 654          3.7  화~일 11:30 ~ 21:00
# 655          4.0  화~일 11:30 ~ 21:00
# 656          4.6  화~일 11:30 ~ 21:00
# 657          3.9  화~일 11:30 ~ 21:00
#
#                                                 이미지url     가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
# ..                                                 ...     ...
# 653  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
# 654  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
# 655  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
# 656  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
# 657  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우래옥 본점
#
#                          가게 주소
# 0    서울 중구 창경궁로 62-29 (우)04546
# 1    서울 중구 창경궁로 62-29 (우)04546
# 2    서울 중구 창경궁로 62-29 (우)04546
# 3    서울 중구 창경궁로 62-29 (우)04546
# 4    서울 중구 창경궁로 62-29 (우)04546
# ..                         ...
# 653  서울 중구 창경궁로 62-29 (우)04546
# 654  서울 중구 창경궁로 62-29 (우)04546
# 655  서울 중구 창경궁로 62-29 (우)04546
# 656  서울 중구 창경궁로 62-29 (우)04546
# 657  서울 중구 창경궁로 62-29 (우)04546
#
# [658 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0                                   가격은 살짝 비싸지만 맛있긴함 굿   5        25
# 1    사전예약을 했지만 지정한 룸의 비어 있는 네자리중 선택권 없이 지정한 입구쪽애 앉으...   1         2
# 2    예약을 미리 하고 동파육은 예약할때 주문을 해놨음에도 불구하고 예약시간보다 일찍 들...   1         1
# 3    서비스 그리 좋지 않은 편. 비싼 가격에 비해 평범하고 멘보샤와 동파육을 같이 시켰...   3       236
# 4                                                        1       395
# ..                                                 ...  ..       ...
# 173                                                      5        42
# 174         절대 권하고 싶지 않다. 돈 쓰고 시간 쓰고 기분 버리고 싶은 분들께 강추!   1        16
# 175  먹고있는데 접시를 막 치움.제대로 음식맛을 못느낌.열받음..다음타임 손님받는것때문인...   1       113
# 176  동파육 퍽퍽함, 요리,식사 보통, 튀김류 낫배드. 연희동, 연남동에 수많은 화교중국...   2         8
# 177  맛 은 전체적으로 깔금한편 잘만들엇다고 느끼고 자극적이지도 않고 그다고 싱겁지않는 ...   2         2
#
#     리뷰자 누적 리뷰 개수              영업 시간  \
# 0            4.2  화~일 12:00 ~ 21:00
# 1            2.0  화~일 12:00 ~ 21:00
# 2            1.0  화~일 12:00 ~ 21:00
# 3            3.3  화~일 12:00 ~ 21:00
# 4            1.6  화~일 12:00 ~ 21:00
# ..           ...                ...
# 173          3.8  화~일 12:00 ~ 21:00
# 174          3.4  화~일 12:00 ~ 21:00
# 175          3.9  화~일 12:00 ~ 21:00
# 176          3.1  화~일 12:00 ~ 21:00
# 177          1.5  화~일 12:00 ~ 21:00
#
#                                                 이미지url 가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
# ..                                                 ...  ..
# 173  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
# 174  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
# 175  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
# 176  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
# 177  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  목란
#
#                           가게 주소
# 0    서울 서대문구 연희로15길 21 (우)03703
# 1    서울 서대문구 연희로15길 21 (우)03703
# 2    서울 서대문구 연희로15길 21 (우)03703
# 3    서울 서대문구 연희로15길 21 (우)03703
# 4    서울 서대문구 연희로15길 21 (우)03703
# ..                          ...
# 173  서울 서대문구 연희로15길 21 (우)03703
# 174  서울 서대문구 연희로15길 21 (우)03703
# 175  서울 서대문구 연희로15길 21 (우)03703
# 176  서울 서대문구 연희로15길 21 (우)03703
# 177  서울 서대문구 연희로15길 21 (우)03703
#
# [178 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    웨이팅 길었는데 기다릴만한 맛이었어요!! 직원분들도 친절하시고 메뉴 플레이팅도 정갈...   5         1
# 1            맛있는 메뉴와 친절한 직원분들덕에 맛있는 식사와 좋은시간 보낼수있었습니다~   5         1
# 2    연어에 무슨 문제가 있었는지 생연어를 들고 주방을 왔다갔다 하시더라고요. 후에 나온...   1         8
# 3                                              맛있고 친절함   5        59
# 4    회사 앞이라 오픈런으로 바로 갔어요.후토마끼 깔끔한 맛이라 좋아요.다만, 한입에 먹...   3        10
# ..                                                 ...  ..       ...
# 288  대창덮밥을 기대하고 갔는데, 생각보다 밥에 있는 양념, 절인양파? 와 같은 애들의 ...   2         4
# 289                                  맛있어요 엄청줄서서먹을곳은아니다   4        20
# 290                               내부가 좀 시끄럽지만 음식 맛있어요.   5        19
# 291  스테이크 덮밥은 양이 낙낙 했고 함께 먹는 소스도 맛있었고 고기 아래 볶은 야채들도...   5        41
# 292                                          대창덮밥 맛나네영   4       986
#
#     리뷰자 누적 리뷰 개수            영업 시간  \
# 0            5.0  일 11:30 ~ 21:00
# 1            5.0  일 11:30 ~ 21:00
# 2            4.1  일 11:30 ~ 21:00
# 3            2.9  일 11:30 ~ 21:00
# 4            3.1  일 11:30 ~ 21:00
# ..           ...              ...
# 288          3.5  일 11:30 ~ 21:00
# 289          3.0  일 11:30 ~ 21:00
# 290          3.6  일 11:30 ~ 21:00
# 291          4.2  일 11:30 ~ 21:00
# 292          3.5  일 11:30 ~ 21:00
#
#                                                 이미지url 가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
# ..                                                 ...  ..
# 288  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
# 289  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
# 290  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
# 291  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
# 292  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진작
#
#                            가게 주소
# 0    서울 중구 수표로12길 12 1층 (우)04555
# 1    서울 중구 수표로12길 12 1층 (우)04555
# 2    서울 중구 수표로12길 12 1층 (우)04555
# 3    서울 중구 수표로12길 12 1층 (우)04555
# 4    서울 중구 수표로12길 12 1층 (우)04555
# ..                           ...
# 288  서울 중구 수표로12길 12 1층 (우)04555
# 289  서울 중구 수표로12길 12 1층 (우)04555
# 290  서울 중구 수표로12길 12 1층 (우)04555
# 291  서울 중구 수표로12길 12 1층 (우)04555
# 292  서울 중구 수표로12길 12 1층 (우)04555
#
# [293 rows x 8 columns]
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0                                        남자 직원 싸가지 없어요   1         1
# 1    맥주나 라떼 맛이 많이 없습니다.. 살면서 마신 맥주중 단연 최악여행가서 전날 저녁...   1         7
# 2    사진 찍으면 예쁘게 나오는 곳인테리어랑 넓은 거 생각하면 비싸가는 생각은 안 듭니다...   4         1
# 3    할아버지피자 완전 맛있더라구요 강추 가격은 비싼편이지만 분위기 좋고 여기서 이런맛이...   4        36
# 4                                         터무늬 없이 비싼 가격   3       285
# ..                                                 ...  ..       ...
# 128                                    음료랑 음식이 너무 비싸네요   2        11
# 129  넓고 햇살도 좋고 음료도 맛있었어요! 자릿값이라 어쩔 수는 없지만 아이스 음료 얼음...   3       115
# 130  형의 평점은객관적이다 1-5점으로 계산한다.주차- 1점 (뚜벅이들에겐 노상관)맛- ...   4        16
# 131                넓은 공간, 맛있는 요리들! 다만 가격이 조금 비싸 1점 뺐음.   4         7
# 132  일단 쓸데없이 비싼 음료값+세련되어 보이려고 했지만 별로 감각없는 공간+믿을 수 없...   2        72
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            1.0  매일 11:00 ~ 22:00
# 1            2.9  매일 11:00 ~ 22:00
# 2            4.0  매일 11:00 ~ 22:00
# 3            3.6  매일 11:00 ~ 22:00
# 4            4.0  매일 11:00 ~ 22:00
# ..           ...               ...
# 128          4.3  매일 11:00 ~ 22:00
# 129          2.8  매일 11:00 ~ 22:00
# 130          2.6  매일 11:00 ~ 22:00
# 131          3.9  매일 11:00 ~ 22:00
# 132          4.1  매일 11:00 ~ 22:00
#
# ...
# 376  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진주회관
# 377  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  진주회관
#
#                          가게 주소
# 0    서울 중구 세종대로11길 26 (우)04513
# 1    서울 중구 세종대로11길 26 (우)04513
# 2    서울 중구 세종대로11길 26 (우)04513
# 3    서울 중구 세종대로11길 26 (우)04513
# 4    서울 중구 세종대로11길 26 (우)04513
# ..                         ...
# 373  서울 중구 세종대로11길 26 (우)04513
# 374  서울 중구 세종대로11길 26 (우)04513
# 375  서울 중구 세종대로11길 26 (우)04513
# 376  서울 중구 세종대로11길 26 (우)04513
# 377  서울 중구 세종대로11길 26 (우)04513
#
# [378 rows x 8 columns]
#                                                    리뷰  별점 리뷰자 평균 평점  \
# 0   사람  보아  가면서 영업 하십니까 ? 먹는 음식  갖고 장난 치면 . 아니 됍니다...   1         9
# 1                                          가족모임하기좋아요오   5         1
# 2   그냥 자리만 괜찮음. 굳이 이런데 와서 밥을 먹어야 하나 싶은 수준인데 멋모르고 많...   1        25
# 3   음식맛이 별로..뭔가 부족한맛.맛깔스럽지않음서빙하는분들 매너가 부족해요반찬리필 요청...   2         1
# 4                             가족모임으로 딱이에요! 맛없는 게 없었어요   4       217
# 5          감사합니다 잘 먹었습니다 강남인데 가격도 착합니다 수고하세여 번창하세요 ~~   5        50
# 6   오랜만에 갔는데 가격이 조금 올랐지만, 여전히 맛있네요 ㅎㅎ 대기가 좀 있지만 밥도...   5        44
# 7   이만한 한정식 잠실에서는 찾기 어렵네요  직원들도 친절하고 가족이랑 즐겁게 한끼하기...   4        64
# 8                                                       5         1
# 9                       주말 대기시간 1시간...먹으라는거지 말라는건지...   1         7
# 10  아산병원 갈일이 있어 들렸던곳인데기대보다 너무 괜찮았습니다돌솥밥ㆍ간장게장ㆍ간단한 쌈...   5         5
# 11                                                      3        25
# 12  어르신들 때문에 가게되었는데 음식 맛은 그럭저럭 괜찮은것과 별로인것도 섞여있어 먹을...   2         6
# 13  초등학생 시절 좌식일때부터 참 많이도 갔던 거 같아요. 요즘 산들해는 성인들끼리 가...   3       144
# 14  친절하시고, 점심에는 기다려야 하는데 대기석도 있고 어르신들 모시고 가기 괜찮아요....   5        44
# 15                                            괜찮은 한정식   3        91
# 16  세시 브레이크타임이라고 그때까지만 오면 된다고 해서 시부모님 모시고 갔은데 55분에...   1         2
# 17  메뉴 : 한정식보쌈 수육은 말라 비틀어져 있고 생선 역시 튀긴 지 좀 된 미즈근한....   1       333
# 18                                                      5        32
# 19              잡채는 한덩어리로 분리도안되고 음...다시는 안가요 별하나도 아깝네   1         5
# 20  8월 13일 오후 4시 반쯤 전화 응대하신 남자 직원분 너무 불친절합니다. 직접 밥...   1        12
# 21  사람 마다 다르겠지만전 오늘 오랫만에 잘먹었어요2시간 주차무료 식사 큰 판에나오고 ...   5         6
# 22  음식부터 이상한 냄새나요한정식치고 가격대비 먹을거 없는...그저 종류만 다양한 그뿐...   1         1
# 23    일단 식당을 찾기가 어려움주차 안좋음들어서자마자 카운터 여자분 불친절교육 받고 오신듯   1        30
# 24  어르신들 모시고 갈만한 곳이라고 생각. 근데 은근 손이 가는 반찬이... 별로 없습니다.   4       431
# 25                   주차최악.  지하오층 파킹.점심시간 웨이팅 안내 엉망...   1        25
# 26                         정식 시키니 이런 그릇에 밥 먹으라고 나오네요.   1       350
# 27                                     많이 아쉬웠어요......   1         4
# 28                          음식종류만 많지 음식맛은..밥이 제일 나았어요   1         1
# 29                                                      4         2
# 30  어른들 모시고 한정식 먹으러가기 괜찮음. 특별한 맛은 아니고 음식이 정갈하게 나옴....   4       495
# 31                카운터 남자 직원 불친절 끝판왕예약시간 지나도 준비 안되어 있음   1        56
# 32      솔직 방문기...!https://choeseunggu.tistory.com/525   4       266
# 33  이 가격에 이 정도 품질 및 종류로 먹을수 있는  한정식은 손에 꼽는다여기가 별로라...   5        47
# 34  가족끼리 가기 좋음주로 나물 반찬이 나와서 부모님들께서 좋아하심 깔끔하게 큰 한상으...   3       135
# 35  보쌈 및 간장게장 등 반찬 무한 리필. 점심에 예약 안하면 줄 서야 함. 줄 서서 ...   3        32
# 36  동네 한정식집 이상이하도 아닌듯. 가성비도 가격이 너무 많이 올랐음. 그래도 평균보...   3       100
# 37                                               무난무난   3         4
# 38                              기본이 안된집카운터부터 김새고맛도 별로   1        29
# 39                                  돌솥밥.반찬이 정갈하니 맛나네요   4         4
# 40  여기맛없다는것들은똥입인가한정식통틀어최고임다만대형차가주차장에못들어가공원에대야함짜증밀려...   4       138
# 41  졸라 맛없음 반찬들이 하나같이 니맛도 내맛도 아니고 개밍밍. 가짓수만 많지 실속은 ...   1        98
# 42                                       갈수록 별로가 되어간다   1         5
# 43                                   아내와 맛있게 먹고 왔습니다.   4        63
# 44  반찬은 진짜 많이 나오고, 게장은 제 입맛에는 진짜 별로 였어요ㅠㅠ 잡채는 진짜 맛...   3        90
# 45  항상 웨이팅이 길긴하지만 만족스러워요. 모든 반찬(보쌈과 간장게장 포함)이 리필 가...   5       140
# 46  롯데타워 구경갔다가 한식좋아하는 울 남편님때문에 갔는데 전체적으로 만족스러웠어요.개...   5        16
# 47                                                      4        64
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 0           1.4  매일 11:30 ~ 21:00
# 1           5.0  매일 11:30 ~ 21:00
# 2           3.1  매일 11:30 ~ 21:00
# 3           2.0  매일 11:30 ~ 21:00
# 4           3.8  매일 11:30 ~ 21:00
# 5           5.0  매일 11:30 ~ 21:00
# 6           4.2  매일 11:30 ~ 21:00
# 7           3.7  매일 11:30 ~ 21:00
# 8           5.0  매일 11:30 ~ 21:00
# 9           2.6  매일 11:30 ~ 21:00
# 10          4.8  매일 11:30 ~ 21:00
# 11          3.0  매일 11:30 ~ 21:00
# 12          2.3  매일 11:30 ~ 21:00
# 13          3.9  매일 11:30 ~ 21:00
# 14          5.0  매일 11:30 ~ 21:00
# 15          3.2  매일 11:30 ~ 21:00
# 16          3.0  매일 11:30 ~ 21:00
# 17          3.5  매일 11:30 ~ 21:00
# 18          4.7  매일 11:30 ~ 21:00
# 19          2.4  매일 11:30 ~ 21:00
# 20          3.4  매일 11:30 ~ 21:00
# 21          3.7  매일 11:30 ~ 21:00
# 22          1.0  매일 11:30 ~ 21:00
# 23          2.1  매일 11:30 ~ 21:00
# 24          4.0  매일 11:30 ~ 21:00
# 25          4.0  매일 11:30 ~ 21:00
# 26          2.5  매일 11:30 ~ 21:00
# 27          3.3  매일 11:30 ~ 21:00
# 28          1.0  매일 11:30 ~ 21:00
# 29          4.5  매일 11:30 ~ 21:00
# 30          4.4  매일 11:30 ~ 21:00
# 31          2.4  매일 11:30 ~ 21:00
# 32          4.1  매일 11:30 ~ 21:00
# 33          2.3  매일 11:30 ~ 21:00
# 34          3.3  매일 11:30 ~ 21:00
# 35          3.6  매일 11:30 ~ 21:00
# 36          3.5  매일 11:30 ~ 21:00
# 37          4.5  매일 11:30 ~ 21:00
# 38          2.8  매일 11:30 ~ 21:00
# 39          4.8  매일 11:30 ~ 21:00
# 40          3.2  매일 11:30 ~ 21:00
# 41          3.6  매일 11:30 ~ 21:00
# 42          2.6  매일 11:30 ~ 21:00
# 43          3.6  매일 11:30 ~ 21:00
# 44          3.9  매일 11:30 ~ 21:00
# 45          4.4  매일 11:30 ~ 21:00
# 46          4.1  매일 11:30 ~ 21:00
# 47          3.4  매일 11:30 ~ 21:00
#
#                                                이미지url      가게명  \
# 0   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 1   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 2   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 3   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 4   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 5   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 6   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 7   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 8   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 9   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 10  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 11  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 12  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 13  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 14  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 15  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 16  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 17  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 18  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 19  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 20  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 21  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 22  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 23  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 24  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 25  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 26  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 27  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 28  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 29  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 30  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 31  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 32  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 33  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 34  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 35  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 36  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 37  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 38  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 39  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 40  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 41  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 42  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 43  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 44  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 45  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 46  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
# 47  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  산들해 송파점
#
#                                가게 주소
# 0   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 1   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 2   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 3   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 4   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 5   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 6   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 7   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 8   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 9   서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 10  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 11  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 12  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 13  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 14  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 15  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 16  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 17  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 18  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 19  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 20  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 21  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 22  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 23  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 24  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 25  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 26  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 27  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 28  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 29  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 30  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 31  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 32  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 33  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 34  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 35  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 36  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 37  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 38  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 39  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 40  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 41  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 42  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 43  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 44  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 45  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 46  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
# 47  서울 송파구 위례성대로 6 현대토픽스 2층 (우)05544
#                                                     리뷰  별점 리뷰자 평균 평점  \
# 0    목살 최고 맛집육즙 장난아니고 엄청 부드러움비지찌개도 굿단점은 테이블 가까워서 좁은...   5        74
# 1                                                        5        33
# 2    본점이라 다른가 아무튼 맛 좋고 구워주기도 하고 웨이팅만 잘 버텨주면 갈만한 곳 목...   4        26
# 3    여기가 왜 이렇게 유명한지 도저히 이해가 안됨. 목살,삼겹,갈매기살 먹었는데 고기는...   2        41
# 4    여사장 술에취해 직원들에 소리지름. 고기먹다 민망해서 혼났네. 재수없게 내가갈때마다...   1         1
# ..                                                 ...  ..       ...
# 148  어제 밤에 영화보고 지인들 데리고 맛난집 있다드라 하고 5명을 데리고 갔는데..다들...   1         3
# 149                                                존맛탱   5         6
# 150                                          맛있다멋있다죽인다   5       215
# 151                        최고최고최고. 맛 최고 분위기 최고 서비스 최고!   5       163
# 152                                       목살 정말 맛있게 구움   5       127
#
#     리뷰자 누적 리뷰 개수             영업 시간  \
# 0            4.3  매일 14:00 ~ 20:50
# 1            2.9  매일 14:00 ~ 20:50
# 2            3.6  매일 14:00 ~ 20:50
# 3            2.9  매일 14:00 ~ 20:50
# 4            1.0  매일 14:00 ~ 20:50
# ..           ...               ...
# 148          2.3  매일 14:00 ~ 20:50
# 149          4.3  매일 14:00 ~ 20:50
# 150          4.1  매일 14:00 ~ 20:50
# 151          4.7  매일 14:00 ~ 20:50
# 152          4.7  매일 14:00 ~ 20:50
#
#                                                 이미지url        가게명  \
# 0    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
# 1    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
# 2    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
# 3    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
# 4    '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
# ..                                                 ...        ...
# 148  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
# 149  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
# 150  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
# 151  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
# 152  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  땅코참숯구이 본점
#
#                             가게 주소
# 0    서울 성동구 행당로17길 26 1층 (우)04715
# 1    서울 성동구 행당로17길 26 1층 (우)04715
# 2    서울 성동구 행당로17길 26 1층 (우)04715
# 3    서울 성동구 행당로17길 26 1층 (우)04715
# 4    서울 성동구 행당로17길 26 1층 (우)04715
# ..                            ...
# 148  서울 성동구 행당로17길 26 1층 (우)04715
# 149  서울 성동구 행당로17길 26 1층 (우)04715
# 150  서울 성동구 행당로17길 26 1층 (우)04715
# 151  서울 성동구 행당로17길 26 1층 (우)04715
# 152  서울 성동구 행당로17길 26 1층 (우)04715
#
# [153 rows x 8 columns]
#                                                   리뷰  별점 리뷰자 평균 평점  \
# 0                                                      5         3
# 1  고기,반찬, 뒤에 나오는 후식까지 아주 센스 만점입니다.하지만 직원들중에 너무 불친...   2        10
# 2  불친절하시네요 상당히예약하려 전화하였는데 시종일관 짜증섞인 여자직원분대표분이 보실런...   1         3
# 3                                                      1        22
# 4  완전 맛없음~~~한우고기를 먹었는데 곱창인줄!!!!너무질기네요~~ 서비스는 좋은데 ...   1       174
# 5  점점 최악임. 불이 고장나서 숯불나오는데 20분걸리고, 고기도 직접구워먹어야함. 냉...   1         4
# 6  장모님과 함께 찾은 찾아간 집, 옛날에 우리가 많이 먹었던 청국장 비빕밥을 기억나게...   5        10
# 7                               등심 존맛탱이에요 담엔 스페셜로 ㄱㄱ   5         5
#
#   리뷰자 누적 리뷰 개수             영업 시간  \
# 0          4.7  매일 11:00 ~ 22:00
# 1          1.4  매일 11:00 ~ 22:00
# 2          2.3  매일 11:00 ~ 22:00
# 3          2.2  매일 11:00 ~ 22:00
# 4          2.7  매일 11:00 ~ 22:00
# 5          3.0  매일 11:00 ~ 22:00
# 6          5.0  매일 11:00 ~ 22:00
# 7          4.0  매일 11:00 ~ 22:00
#
#                                               이미지url       가게명  \
# 0  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  강강술래 시흥점
# 1  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  강강술래 시흥점
# 2  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  강강술래 시흥점
# 3  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  강강술래 시흥점
# 4  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  강강술래 시흥점
# 5  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  강강술래 시흥점
# 6  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  강강술래 시흥점
# 7  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  강강술래 시흥점
#
#                                  가게 주소
# 0  서울 금천구 시흥대로 193 금천ICT타워 2층 (우)08635
# 1  서울 금천구 시흥대로 193 금천ICT타워 2층 (우)08635
# 2  서울 금천구 시흥대로 193 금천ICT타워 2층 (우)08635
# 3  서울 금천구 시흥대로 193 금천ICT타워 2층 (우)08635
# 4  서울 금천구 시흥대로 193 금천ICT타워 2층 (우)08635
# 5  서울 금천구 시흥대로 193 금천ICT타워 2층 (우)08635
# 6  서울 금천구 시흥대로 193 금천ICT타워 2층 (우)08635
# 7  서울 금천구 시흥대로 193 금천ICT타워 2층 (우)08635
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 112
#     110 addr = [i.strip() for i in addr.split('\n')]
#     111 addr = ' '.join(addr)
# --> 112 store_operate_day = store_operate_day.text
#     113 store_operate_day = store_operate_day.replace('\n', '')
#     115 #이미지 url 추가하기
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
total_df

# %%
total_df.to_csv('sample.csv')

# %%
html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
soup = BeautifulSoup(html, 'html.parser')
try:
    store_name = soup.find(name = 'h2', attrs = {'class':'tit_location'})
    addr = soup.find(name = 'span', attrs = {'class':'txt_address'})
    total_strong = soup.find(name="strong", attrs={"class": "total_evaluation"})
    tot_num = total_strong.find(name="span", attrs={"class": "color_b"}) # 등록된 리뷰 갯수
    contents_div = soup.find(name='div', attrs={"class": "evaluation_review"}) #리뷰 영역. 별점, 내용
    rates=contents_div.find_all(name="span", attrs={"class": "ico_star star_rate"}) # 별점값 목록
    reviews = contents_div.find_all(name="p", attrs={"class": "txt_comment"}) # 리뷰 목록
except:
    pass
    #continue
     # try 구문에서 오류 발생된 경우 다음 페이지로 이동 
#     # 리뷰의 1페이지 정보를 df에 저장
rate_list =[]
review_list =[]
for i in range(len(rates)):
    rate_value = rates[i].find(name='span', attrs={"class": "ico_star"})
    style_value = rate_value.get('style')
    if style_value == 'width:20%;':
        rate = 1
    elif style_value == 'width:40%;':
        rate = 2
    elif style_value == 'width:60%;':
        rate = 3
    elif style_value == 'width:80%;':
        rate = 4
    elif style_value == 'width:100%;':
        rate = 5
    rate_list.append(rate)    
for review in reviews:
    rev_span = review.find(name="span")
    if rev_span is not None and rev_span.text:
        rev = rev_span.text
    else:
        rev = ''
    review_list.append(rev)
store_name = store_name.text
addr = addr.text 
df['score'] = rate_list
df['review'] = review_list
df['store_name'] = store_name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 41
#      39 store_name = store_name.text
#      40 addr = addr.text
# ---> 41 df['score'] = rate_list
#      42 df['review'] = review_list
#      43 df['store_name'] = store_name
#
# File c:\Users\dddf\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File c:\Users\dddf\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\dddf\anaconda3\lib\site-packages\pandas\core\frame.py:4538, in DataFrame._sanitize_column(self, value)
#    4535     return _reindex_for_setitem(value, self.index)
#    4537 if is_list_like(value):
# -> 4538     com.require_length_match(value, self.index)
#    4539 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File c:\Users\dddf\anaconda3\lib\site-packages\pandas\core\common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (228) does not match length of index (3)

# %%
df
# Out:
#    score                                             review store_name
# 0      5  치즈닭갈비 최고..! 치즈 풍미가 장난이 아니에요조리되어 나와서 바로 먹을 수 있고...  장인닭갈비 강남점
# 1      5  치즈 있는 닭갈비 처음 먹어봤는데 진짜 맛도리였어요. 여기 닭갈비가 매워서 치즈는 ...  장인닭갈비 강남점
# 2      3                  맛은 그냥 보통임. 가운데에 치즈가 있어서 보기에는 괜춘함.  장인닭갈비 강남점

# %%
html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
soup = BeautifulSoup(html, 'html.parser')

contents_div = soup.find(name='div', attrs={"class": "evaluation_review"}) #리뷰 영역. 별점, 내용
rates=contents_div.find_all(name="span", attrs={"class": "ico_star star_rate"}) # 별점값 목록
reviews = contents_div.find_all(name="p", attrs={"class": "txt_comment"}) # 리뷰 목록

# %%
reviews
# Out:
# [<p class="txt_comment"><span>치즈닭갈비 최고..! 치즈 풍미가 장난이 아니에요<br/>조리되어 나와서 바로 먹을 수 있고 양이 많아서 좋았어요<br/>배불러서 볶음밥 못먹음 ㅜㅜ</span><button class="btn_fold" type="button">더보기</button></p>,
#  <p class="txt_comment"><span>치즈 있는 닭갈비 처음 먹어봤는데 진짜 맛도리였어요. 여기 닭갈비가 매워서 치즈는 필수.. 그리고 강남역 한복판.. 사람들로 엄청 북적이는데 가게 내부는 넓어서 괜찮았어요. 저녁에는 시간에 따라 웨이팅도 있는듯.</span><button class="btn_fold" type="button">더보기</button></p>,
#  <p class="txt_comment"><span>맛은 그냥 보통임. 가운데에 치즈가 있어서 보기에는 괜춘함.</span><button class="btn_fold" type="button">더보기</button></p>,
#  <p class="txt_comment txt_fold"><span>3/3일 방문 저녁 9시쯤 방문하여 밥먹는데 벽에서 쥐나와서 활보함... 쥐나왔는데 직원들은 별 개의치 않고 손님들만 개 기겁함 살다살다 식당에서 큰 쥐가 돌아다니는거 처음보네 덕분에 집갈 때 그림자만 봐도 쥐인가 식겁함... 어지간하면 댓글 안남기는데 이게 첫 댓글임</span><button class="btn_fold" type="button">더보기</button></p>,
#  <p class="txt_comment"><span>직원분이 너~무 불친절하세요<br/>불키라는 말도 안해주고 계속 명령조로 얘기하십니다ㅎㅎ</span><button class="btn_fold" type="button">더보기</button></p>,
#  <p class="txt_comment"><span>닭갈비 맛있습니다. 늘 사람이 많고 정신 없어서 서비스가 좀 아쉽습니다</span><button class="btn_fold" type="button">더보기</button></p>,
#  <p class="txt_comment"><span>고냥저냥</span><button class="btn_fold" type="button">더보기</button></p>,
#  <p class="txt_comment txt_fold"><span>웨이팅 - 금요일 강남이여도 금방빠지긴 했습니다.<br/>위생 - 컵이 제대로 닦이지 않은걸 줘서 직원분 콜을 했는데 바꿔드릴까요? 라고 물어봅니다.<br/>직원 - 주문이 잘못들어간걸 다시 원래 주문대로 바꿔주면서 바꿔드렸어요~ 하고 빌지 툭 던지고 갑니다.<br/>설명 - 음식에 대한 설명을 하려는거 같은데 안하느니만 못하게 하십니다.<br/>건강 - 이거 먹고 배탈났습니다.<br/>재방문 - 안합니다.</span><button class="btn_fold" type="button">더보기</button></p>]

# %%
more_text_in_store = driver.find_element_by_xpath('//*[@id="mArticle"]/div[7]/div[3]/a/span[1]')
actions = ActionChains(driver)#스크롤내리기
actions.move_to_element(more_text_in_store).perform()

# %%
# while True:

    # 페이지 숫자의 테그
text_more = driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > a > span.txt_more')
actions = ActionChains(driver) #스크롤내리기
actions.move_to_element(text_more).perform()
text_more.click()
time.sleep(2)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
contents_div = soup.find(name='div', attrs={"class": "evaluation_review"}) #리뷰 영역. 별점, 내용
rates=contents_div.find_all(name="span", attrs={"class": "ico_star star_rate"}) # 별점값 목록
reviews = contents_div.find_all(name="p", attrs={"class": "txt_comment"}) # 리뷰 목록
review_list =[]
for i in range(len(rates)):
    rate_value = rates[i].find(name='span', attrs={"class": "ico_star"})
    style_value = rate_value.get('style')
    if style_value == 'width:20%;':
        rate = 1
    elif style_value == 'width:40%;':
        rate = 2
    elif style_value == 'width:60%;':
        rate = 3
    elif style_value == 'width:80%;':
        rate = 4
    elif style_value == 'width:100%;':
        rate = 5
    rate_list.append(rate)
for review in reviews:
    rev_span = review.find(name="span")
    if rev_span is not None and rev_span.text:
        rev = rev_span.text
    else:
        rev = ''
    review_list.append(rev)
    more_df = pd.DataFrame(rates, review_list, store_name, addr, columns= ['score', 'review', 'store_name', 'addr'])   
#         for rate, review in zip(rates, reviews):
#             row=[rate.text[0], review.find(name="span").text]
#             series = pd.Series(row, index=df.columns)
#             df = df.append(series, ignore_index=True)
    # except:
    #     break
# Out:
#   Cell In[74], line 41
#     except:
#     ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#    score                                             review store_name
# 0      5  치즈닭갈비 최고..! 치즈 풍미가 장난이 아니에요조리되어 나와서 바로 먹을 수 있고...  장인닭갈비 강남점
# 1      5  치즈 있는 닭갈비 처음 먹어봤는데 진짜 맛도리였어요. 여기 닭갈비가 매워서 치즈는 ...  장인닭갈비 강남점
# 2      3                  맛은 그냥 보통임. 가운데에 치즈가 있어서 보기에는 괜춘함.  장인닭갈비 강남점

# %%
more_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 more_df
#
# NameError: name 'more_df' is not defined
